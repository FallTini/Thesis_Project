# %% [markdown]
# # ISIC 2024 - Skin Cancer Detection with 3D-TB using KerasCV and Keras
#
# > The goal of this competition is to detect skin cancers in lesions cropped from 3D total body photographs.
#
# <div align="center">
#   <image src="https://i.ibb.co/PYLN6QR/isic2024.jpg">
# </div>
#
# This notebook guides through training and deploying a Deep Learning model for skin cancer detection using skin lesion data from 3D total body photographs. Specifically, we'll employ the EfficientNetV2 backbone from KerasCV on the competition dataset. The notebook integrates both image data and tabular features (e.g., age, sex) to enhance skin cancer detection.

# %% [markdown]
# # | Import Libraries

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow" # other options: tensorflow or torch

import keras_cv
import keras
from keras import ops
import tensorflow as tf

import cv2
import pandas as pd
import numpy as np
from glob import glob
from tqdm.notebook import tqdm
import joblib

import matplotlib.pyplot as plt

# %% [markdown]
# ## Library Versions

# %%
print("TensorFlow:", tf.__version__)
print("Keras:", keras.__version__)
print("KerasCV:", keras_cv.__version__)
# Out:
# TensorFlow: 2.16.1
# Keras: 3.3.3
# KerasCV: 0.9.0

# %% [markdown]
# # | Configuration

# %%
class CFG:
    verbose = 1  # Verbosity
    seed = 42  # Random seed
    neg_sample = 0.01 # Downsample negative calss
    pos_sample = 5.0  # Upsample positive class
    preset = "efficientnetv2_b2_imagenet"  # Name of pretrained classifier
    image_size = [128, 128]  # Input image size
    epochs = 200 # Training epochs
    batch_size = 256  # Batch size
    lr_mode = "cos" # LR scheduler mode from one of "cos", "step", "exp"
    class_names = ['target']
    num_classes = 1

# %% [markdown]
# #| Reproducibility
# Sets value for random seed to produce similar result in each run.

# %%
keras.utils.set_random_seed(CFG.seed)

# %% [markdown]
# # | Dataset Path

# %%
BASE_PATH = "/kaggle/input/isic-2024-challenge"

# %% [markdown]
# # | Meta Data
#
# In this dataset, following information is available:
#
# - **train-image/**: Contains image files for the training set (provided for train only).
# - **train-image.hdf5**: Training image data stored in a single HDF5 file, where each image is indexed by its `isic_id`.
# - **train-metadata.csv**: Metadata corresponding to the training set, including:
#   - `isic_id`: Unique image ID used to query images in the HDF5 file.
#   - `patient_id`: Unique patient ID.
#   - `sex`: Gender of the patient.
#   - `age_approx`: Approximate age of the patient.
#   - `anatom_site_general`: Location of the lesion.
#   - Other relevant metadata fields.
# - **test-image.hdf5**: Testing image data stored in a single HDF5 file, initially containing 3 testing examples to validate the inference pipeline. Upon notebook submission, this file is replaced with the full hidden testing set, which contains approximately 500,000 images.
# - **test-metadata.csv**: Metadata corresponding to the testing subset.

# %%
# Train + Valid
df = pd.read_csv(f'{BASE_PATH}/train-metadata.csv')
df = df.ffill()
display(df.head(2))

# Testing
testing_df = pd.read_csv(f'{BASE_PATH}/test-metadata.csv')
testing_df = testing_df.ffill()
display(testing_df.head(2))
# Out:
# /tmp/ipykernel_23/4057045618.py:2: DtypeWarning: Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'{BASE_PATH}/train-metadata.csv')
#         isic_id  target  patient_id  age_approx   sex anatom_site_general  \
# 0  ISIC_0015670       0  IP_1235828        60.0  male     lower extremity
# 1  ISIC_0015845       0  IP_8170065        60.0  male           head/neck
#
#    clin_size_long_diam_mm          image_type tbp_tile_type   tbp_lv_A  ...  \
# 0                    3.04  TBP tile: close-up     3D: white  20.244422  ...
# 1                    1.10  TBP tile: close-up     3D: white  31.712570  ...
#
#     lesion_id  iddx_full  iddx_1  iddx_2  iddx_3  iddx_4  iddx_5  \
# 0         NaN     Benign  Benign     NaN     NaN     NaN     NaN
# 1  IL_6727506     Benign  Benign     NaN     NaN     NaN     NaN
#
#    mel_mitotic_index  mel_thick_mm  tbp_lv_dnn_lesion_confidence
# 0                NaN           NaN                     97.517282
# 1                NaN           NaN                      3.141455
#
# [2 rows x 55 columns]
#         isic_id  patient_id  age_approx     sex anatom_site_general  \
# 0  ISIC_0015657  IP_6074337        45.0    male     posterior torso
# 1  ISIC_0015729  IP_1664139        35.0  female     lower extremity
#
#    clin_size_long_diam_mm          image_type tbp_tile_type  tbp_lv_A  \
# 0                    2.70  TBP tile: close-up        3D: XP  22.80433
# 1                    2.52  TBP tile: close-up        3D: XP  16.64867
#
#    tbp_lv_Aext  ...  tbp_lv_radial_color_std_max  tbp_lv_stdL  tbp_lv_stdLExt  \
# 0    20.007270  ...                     0.304827     1.281532        2.299935
# 1     9.657964  ...                     0.000000     1.271940        2.011223
#
#    tbp_lv_symm_2axis  tbp_lv_symm_2axis_angle   tbp_lv_x     tbp_lv_y  \
# 0           0.479339                       20 -155.06510  1511.222000
# 1           0.426230                       25 -112.36924   629.535889
#
#      tbp_lv_z                                        attribution  \
# 0  113.980100             Memorial Sloan Kettering Cancer Center
# 1  -15.019287  Frazer Institute, The University of Queensland...
#
#    copyright_license
# 0              CC-BY
# 1              CC-BY
#
# [2 rows x 44 columns]

# %% [markdown]
# # | Handle Class Imbalance

# %% [markdown]
# ## Sample Data
#
# There is a significant class imbalance in the dataset, with a large number of negative samples compared to positive samples. To address this issue, the negative class will be downsampled and upsample the positive class. To experiment with full dataset, simply adjust the `pos_sample` and `neg_sample` settings in `CFG`.

# %%
print("Class Distribution Before Sampling (%):")
display(df.target.value_counts(normalize=True)*100)

# Sampling
positive_df = df.query("target==0").sample(frac=CFG.neg_sample, random_state=CFG.seed)
negative_df = df.query("target==1").sample(frac=CFG.pos_sample, replace=True, random_state=CFG.seed)
df = pd.concat([positive_df, negative_df], axis=0).sample(frac=1.0)

print("\nCalss Distribution After Sampling (%):")
display(df.target.value_counts(normalize=True)*100)
# Out:
# Class Distribution Before Sampling (%):
# target
# 0    99.902009
# 1     0.097991
# Name: proportion, dtype: float64
# Calss Distribution After Sampling (%):
# target
# 0    67.09645
# 1    32.90355
# Name: proportion, dtype: float64

# %% [markdown]
# ## Class Weight
#
# Even after downsampling the negative class and upsampling the positive class, there remains a significant class imbalance. To further address this imbalance during training, loss weighting will be used. This technique ensures that the model weights are updated more heavily for the positive samples, thereby reducing the bias towards the negative class. The following code computes the class weights for the loss:

# %%
from sklearn.utils.class_weight import compute_class_weight

# Assume df is your DataFrame and 'target' is the column with class labels
class_weights = compute_class_weight('balanced', classes=np.unique(df['target']), y=df['target'])
class_weights = dict(enumerate(class_weights))
print("Class Weights:", class_weights)
# Out:
# Class Weights: {0: 0.7451959071624656, 1: 1.519592875318066}

# %% [markdown]
# # | Load Image Byte String
#
# In this competition, images are provided as byte strings. The following code snippet demonstrates how to load these images into memory. One might wonder why the provided `jpeg` images aren't being used in the `/train-image` folder for training. This is because testing images are not provided as JPEG images; instead, they are provided as byte strings. Why use byte strings? They occupy significantly less memory compared to `np.array` representations.

# %%
import h5py

training_validation_hdf5 = h5py.File(f"{BASE_PATH}/train-image.hdf5", 'r')
testing_hdf5 = h5py.File(f"{BASE_PATH}/test-image.hdf5", 'r')

# %% [markdown]
# ## Check Image
#
# Examining a sample image from the provided data is important. This step allows for a closer inspection of the image quality and content, ensuring it meets the requirements for further processing.

# %%
isic_id = df.isic_id.iloc[0]

# Image as Byte String
byte_string = training_validation_hdf5[isic_id][()]
print(f"Byte String: {byte_string[:20]}....")

# Convert byte string to numpy array
nparr = np.frombuffer(byte_string, np.uint8)

print("Image:")
image = cv2.imdecode(nparr, cv2.IMREAD_COLOR)[...,::-1] # reverse last axis for bgr -> rgb
plt.imshow(image);
# Out:
# Byte String: b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00'....
# Image:

# %% [markdown]
# # | Data Split
#
# In the following code,the data will be splitted into `5` stratified folds and use the first fold for training and validation. It's important to note that `StratifiedGroupKFold` is being used to ensure that `patient_id`s do not overlap between the training and validation datasets. This prevents data leakage, where the model could potentially peak at data it should not have access to.
#
# > **Note**: Data leakage can lead to artificially high validation scores that do not reflect real-world performance.

# %%
from sklearn.model_selection import StratifiedGroupKFold

df = df.reset_index(drop=True) # ensure continuous index
df["fold"] = -1
sgkf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=CFG.seed)
for i, (training_idx, validation_idx) in enumerate(sgkf.split(df, y=df.target, groups=df.patient_id)):
    df.loc[validation_idx, "fold"] = int(i)

# Use first fold for training and validation
training_df = df.query("fold!=0")
validation_df = df.query("fold==0")
print(f"# Num Train: {len(training_df)} | Num Valid: {len(validation_df)}")
# Out:
# # Num Train: 4706 | Num Valid: 1266

# %% [markdown]
# ## Class Distribution in Training

# %%
training_df.target.value_counts()
# Out:
# target
# 0    3088
# 1    1618
# Name: count, dtype: int64

# %% [markdown]
# ## Class Distribution in Validation

# %%
validation_df.target.value_counts()
# Out:
# target
# 0    919
# 1    347
# Name: count, dtype: int64

# %% [markdown]
# #| Tabular Features
#
# In this competition, alongside image data, tabular features such as age, sex, and the location of the lesion are available. Previous competitions, like [ISIC 2020](https://www.kaggle.com/c/siim-isic-melanoma-classification/overview), have demonstrated that incorporating these tabular features can significantly enhance model performance. A similar improvement is anticipated here.
#
# The following code snippet provides a method for selecting which tabular features to include. It is encouraged to experiment with various combinations to determine the most effective set.

# %%
# Categorical features which will be one hot encoded
CATEGORICAL_COLUMNS = ["sex", "anatom_site_general",
            "tbp_tile_type","tbp_lv_location", ]

# Numeraical features which will be normalized
NUMERIC_COLUMNS = ["age_approx", "tbp_lv_nevi_confidence", "clin_size_long_diam_mm",
           "tbp_lv_areaMM2", "tbp_lv_area_perim_ratio", "tbp_lv_color_std_mean",
           "tbp_lv_deltaLBnorm", "tbp_lv_minorAxisMM", ]

# Tabular feature columns
FEAT_COLS = CATEGORICAL_COLUMNS + NUMERIC_COLUMNS

# %% [markdown]
# # | DataLoader
#
# This DataLoader is designed to process both `images` and tabular `features` simultaneously as inputs. It applies augmentations like `flip` and `cutout`, with additional options available such as random brightness, contrast, zoom, and rotation. Experimentation with different augmentations is encouraged. More details on the available augmentations in KerasCV can be found [here](https://keras.io/api/keras_cv/layers/preprocessing/).
#
# > Note: Unlike standard augmentations, these augmentations are applied to a batch, enhancing training speed and reducing CPU bottlenecks.

# %%
def build_augmenter():
    # Define augmentations
    aug_layers = [
        keras_cv.layers.RandomCutout(height_factor=(0.02, 0.06), width_factor=(0.02, 0.06)),
        keras_cv.layers.RandomFlip(mode="horizontal"),
        keras_cv.layers.RandomRotation(factor=0.15),    # New: Random rotation
        keras_cv.layers.RandomZoom(height_factor=(-0.2, 0.2), width_factor=(-0.2, 0.2)),  # New: Random zoom
        keras_cv.layers.RandomBrightness(factor=(-0.1, 0.1)),  # New: Random brightness adjustment
    ]

    # Apply augmentations to random samples
    aug_layers = [keras_cv.layers.RandomApply(x, rate=0.5) for x in aug_layers]

    # Build augmentation layer
    augmenter = keras_cv.layers.Augmenter(aug_layers)

    # Apply augmentations
    def augment(inp, label):
        images = inp["images"]
        aug_data = {"images": images}
        aug_data = augmenter(aug_data)
        inp["images"] = aug_data["images"]
        return inp, label
    return augment


def build_decoder(with_labels=True, target_size=CFG.image_size):
    def decode_image(inp):
        # Read jpeg image
        file_bytes = inp["images"]
        image = tf.io.decode_jpeg(file_bytes)

        # Resize
        image = tf.image.resize(image, size=target_size, method="area")

        # Rescale image
        image = tf.cast(image, tf.float32)
        image /= 255.0

        # Reshape
        image = tf.reshape(image, [*target_size, 3])

        inp["images"] = image
        return inp

    def decode_label(label, num_classes):
        label = tf.cast(label, tf.float32)
        label = tf.reshape(label, [num_classes])
        return label

    def decode_with_labels(inp, label=None):
        inp = decode_image(inp)
        label = decode_label(label, CFG.num_classes)
        return (inp, label)

    return decode_with_labels if with_labels else decode_image


def build_dataset(
    isic_ids,
    hdf5,
    features,
    labels=None,
    batch_size=32,
    decode_fn=None,
    augment_fn=None,
    augment=False,
    shuffle=1024,
    cache=True,
    drop_remainder=False,
):
    if decode_fn is None:
        decode_fn = build_decoder(labels is not None)

    if augment_fn is None:
        augment_fn = build_augmenter()

    AUTO = tf.data.experimental.AUTOTUNE

    images = [None]*len(isic_ids)
    for i, isic_id in enumerate(tqdm(isic_ids, desc="Loading Images ")):
        images[i] = hdf5[isic_id][()]

    inp = {"images": images, "features": features}
    slices = (inp, labels) if labels is not None else inp

    ds = tf.data.Dataset.from_tensor_slices(slices)
    ds = ds.cache() if cache else ds
    ds = ds.map(decode_fn, num_parallel_calls=AUTO)
    if shuffle:
        ds = ds.shuffle(shuffle, seed=CFG.seed)
        opt = tf.data.Options()
        opt.deterministic = False
        ds = ds.with_options(opt)
    ds = ds.batch(batch_size, drop_remainder=drop_remainder)
    ds = ds.map(augment_fn, num_parallel_calls=AUTO) if augment else ds
    ds = ds.prefetch(AUTO)
    return ds

# %% [markdown]
# ## Build Training & Validation Dataset
#
# In the following code, **training** and **validation** data loaders will be created.

# %%
## Train
print("# Training:")
training_features = dict(training_df[FEAT_COLS])
training_ids = training_df.isic_id.values
training_labels = training_df.target.values
training_ds = build_dataset(training_ids, training_validation_hdf5, training_features,
                         training_labels, batch_size=CFG.batch_size,
                         shuffle=True, augment=True)

# Valid
print("# Validation:")
validation_features = dict(validation_df[FEAT_COLS])
validation_ids = validation_df.isic_id.values
validation_labels = validation_df.target.values
validation_ds = build_dataset(validation_ids, training_validation_hdf5, validation_features,
                         validation_labels, batch_size=CFG.batch_size,
                         shuffle=False, augment=False)
# Out:
# # Training:
# Loading Images :   0%|          | 0/4706 [00:00<?, ?it/s]
# # Validation:
# Loading Images :   0%|          | 0/1266 [00:00<?, ?it/s]

# %%
feature_space = keras.utils.FeatureSpace(
    features={
        # Categorical features encoded as integers
        "sex": "string_categorical",
        "anatom_site_general": "string_categorical",
        "tbp_tile_type": "string_categorical",
        "tbp_lv_location": "string_categorical",
        # Numerical features to discretize
        "age_approx": "float_discretized",
        # Numerical features to normalize
        "tbp_lv_nevi_confidence": "float_normalized",
        "clin_size_long_diam_mm": "float_normalized",
        "tbp_lv_areaMM2": "float_normalized",
        "tbp_lv_area_perim_ratio": "float_normalized",
        "tbp_lv_color_std_mean": "float_normalized",
        "tbp_lv_deltaLBnorm": "float_normalized",
        "tbp_lv_minorAxisMM": "float_normalized",
    },
    output_mode="concat",
)

# %% [markdown]
# ## Configuring a `FeatureSpace`
#
# To set up how each tabular feature should be preprocessed, `keras.utils.FeatureSpace` is used. A dictionary is passsed to it that maps each feature name to a string describing its type.
#
# - **String Categorical Features**:
#   - Examples: `sex`, `anotm_site_general`
# - **Numerical Features**:
#   - Examples: `tbp_lv_nevi_confidence`, `clin_size_long_diam_mm`
#   - Note: These features will be normalized.
# - **Numerical Discrete Features**:
#   - `age_approx`: Need to discretize this feature into a number of bins.

# %% [markdown]
# ## Adapt Tabular Features
#
# Before the `FeatureSpace` is used to build a model, it needs to be adapted to the training data. During `adapt()`, the `FeatureSpace` will:
#
# - Index the set of possible values for **categorical features**.
# - Compute the mean and variance for **numerical features** to normalize.
# - Compute the value boundaries for the different bins for **numerical features** to discretize.
#
# Note: `adapt()` should be called on a `tf.data.Dataset` that yields dictionaries of feature values – no labels.

# %%
training_ds_with_no_labels = training_ds.map(lambda x, _: x["features"])
feature_space.adapt(training_ds_with_no_labels)

# %% [markdown]
# At this point, the `FeatureSpace` can be called on a dictionary of raw feature values. It will return a single concatenated vector for each sample, combining encoded features.
#
# In the code below, it can be noticed that even though $12$ raw (tabular) features are used, after processing with `FeatureSpace`, a vector of size $71$ is created. This is because operations like one-hot encoding are being applied here.

# %%
for x, _ in training_ds.take(1):
    preprocessed_x = feature_space(x["features"])
    print("preprocessed_x.shape:", preprocessed_x.shape)
    print("preprocessed_x.dtype:", preprocessed_x.dtype)
# Out:
# preprocessed_x.shape: (256, 71)
# preprocessed_x.dtype: <dtype: 'float32'>

# %% [markdown]
# ## Apply Feature Processing
#
# Integrating feature space processing into the data pipeline before the model is crucial. This approach enables asynchronous, parallel preprocessing of data on the CPU, ensuring it is optimized before being fed into the model.

# %%
training_ds = training_ds.map(
    lambda x, y: ({"images": x["images"],
                   "features": feature_space(x["features"])}, y), num_parallel_calls=tf.data.AUTOTUNE)

validation_ds = validation_ds.map(
    lambda x, y: ({"images": x["images"],
                   "features": feature_space(x["features"])}, y), num_parallel_calls=tf.data.AUTOTUNE)

# %% [markdown]
# ## Output Shape of a Batch
#
# Verifying the shape of a batch sample is essential. This step ensures that the dataloader is generating inputs with the correct dimensions, which is critical for the model's performance.

# %%
batch = next(iter(validation_ds))

print("Images:",batch[0]["images"].shape)
print("Features:", batch[0]["features"].shape)
print("Targets:", batch[1].shape)
# Out:
# Images: (256, 128, 128, 3)
# Features: (256, 71)
# Targets: (256, 1)

# %% [markdown]
# ## Dataset Check
#
# Visualizing samples along with their associated labels from the dataset is a vital step. This process helps in understanding the data distribution and ensures that the dataset is correctly labeled.

# %% [markdown]
# #| Loss & Metric
#
# This competition utilizes the Partial Area Under the Curve (pAUC) metric for evaluation. In Keras, a similar metric is ROC AUC, which can be used for approximate evaluation. For optimizing our model, binary cross entropy (BCE) loss from Keras will be used.
#
# It's important to note that BCE loss is sensitive to class imbalance. To mitigate this issue, the class weights will be used which is computed earlier. These weights will prioritize updating the model weights more strongly for the minority class (positive class), thereby mitigating class imbalance.

# %%
# AUC
#auc = keras.metrics.AUC()
metrics = [keras.metrics.BinaryAccuracy(name='accuracy'), keras.metrics.AUC(name='auc'), keras.metrics.Precision(name="precision"), keras.metrics.Recall(name="recall")]

# Loss
loss = keras.losses.BinaryCrossentropy(label_smoothing=0.02)

# %% [markdown]
# #| Modeling
#
# In this notebook, we're using the `EfficientNetV2 B2` backbone from KerasCV's pretrained models to extract features from images. For processing tabular data, `Dense` layers are used. The final layer (head) is a `Dense` layer with a `sigmoid` activation function. The `sigmoid` activation is chosen because the target is binary; `softmax` would've been selected if the target was multiclass.
#
# To explore other backbones, one can simply modify the `preset` in the `CFG` (config). A list of available pretrained backbones can be found on the [KerasCV website](https://keras.io/api/keras_cv/models/).
#
# > **Note**: Since the size of tabular features likely to change due to feature space processing,  `feature_space.get_encoded_features()` is used to determine the final size of the tabular feature vector for building the model.

# %%
# Define input layers
image_input = keras.Input(shape=(*CFG.image_size, 3), name="images")
feat_input = keras.Input(shape=(feature_space.get_encoded_features().shape[1],), name="features")
inp = {"images":image_input, "features":feat_input}

# Branch for image input
backbone = keras_cv.models.EfficientNetV2Backbone.from_preset(CFG.preset)
x1 = backbone(image_input)
x1 = keras.layers.GlobalAveragePooling2D()(x1)
x1 = keras.layers.Dropout(0.2)(x1)

# Branch for tabular/feature input
x2 = keras.layers.Dense(96, activation="selu")(feat_input)
x2 = keras.layers.Dense(128, activation="selu")(x2)
x2 = keras.layers.Dropout(0.1)(x2)

# Concatenate both branches
concat = keras.layers.Concatenate()([x1, x2])

# Output layer
out = keras.layers.Dense(1, activation="sigmoid", dtype="float32")(concat)

# Build model
model = keras.models.Model(inp, out)

# Compile the model
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    loss=loss,
    metrics=metrics,
)

# Model Summary
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ images (InputLayer) │ (None, 128, 128,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ features            │ (None, 71)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ efficient_net_v2b2… │ (None, 4, 4,      │  8,769,374 │ images[0][0]      │
# │ (EfficientNetV2Bac… │ 1408)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 96)        │      6,912 │ features[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1408)      │          0 │ efficient_net_v2… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │     12,416 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1408)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 1536)      │          0 │ dropout[0][0],    │
# │ (Concatenate)       │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │      1,537 │ concatenate_1[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,790,239 (33.53 MB)
#  Trainable params: 8,707,951 (33.22 MB)
#  Non-trainable params: 82,288 (321.44 KB)

# %% [markdown]
# ## Plot Model
#
# As our model is multi-input, it is difficult to understand what is going on inside the architecture. That is where `plot_model` from **Keras** can be very handy. Overall architecture is shown, making it easier to design or recheck our architecture.

# %%
keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, dpi=60)

# %% [markdown]
# #| LR Schedule
#
# A well-structured learning rate schedule is essential for efficient model training, ensuring optimal convergence and avoiding issues such as overshooting or stagnation.

# %%
import math

def get_lr_callback(batch_size=8, mode='cos', epochs=10, plot=False):
    lr_start, lr_max, lr_min = 2.5e-5, 5e-6 * batch_size, 0.8e-5
    lr_ramp_ep, lr_sus_ep, lr_decay = 3, 0, 0.75

    def lrfn(epoch):  # Learning rate update function
        if epoch < lr_ramp_ep: lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
        elif epoch < lr_ramp_ep + lr_sus_ep: lr = lr_max
        elif mode == 'exp': lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
        elif mode == 'step': lr = lr_max * lr_decay**((epoch - lr_ramp_ep - lr_sus_ep) // 2)
        elif mode == 'cos':
            decay_total_epochs, decay_epoch_index = epochs - lr_ramp_ep - lr_sus_ep + 3, epoch - lr_ramp_ep - lr_sus_ep
            phase = math.pi * decay_epoch_index / decay_total_epochs
            lr = (lr_max - lr_min) * 0.5 * (1 + math.cos(phase)) + lr_min
        return lr

    if plot:  # Plot lr curve if plot is True
        plt.figure(figsize=(10, 5))
        plt.plot(np.arange(epochs), [lrfn(epoch) for epoch in np.arange(epochs)], marker='o')
        plt.xlabel('epoch'); plt.ylabel('lr')
        plt.title('LR Scheduler')
        plt.show()

    return keras.callbacks.LearningRateScheduler(lrfn, verbose=False)  # Create lr callback

# %%
inputs, targets = next(iter(training_ds))
images = inputs["images"]
num_images, NUMERIC_COLUMNS = 8, 4

plt.figure(figsize=(4 * NUMERIC_COLUMNS, num_images // NUMERIC_COLUMNS * 4))
for i, (image, target) in enumerate(zip(images[:num_images], targets[:num_images])):
    plt.subplot(num_images // NUMERIC_COLUMNS, NUMERIC_COLUMNS, i + 1)
    image = image.numpy().astype("float32")
    target= target.numpy().astype("int32")[0]

    image = (image - image.min()) / (image.max() + 1e-4)

    plt.imshow(image)
    plt.title(f"Target: {target}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
lr_cb = get_lr_callback(CFG.batch_size, mode="exp", plot=True)

# %% [markdown]
# #| Model Checkpoint
#
# The `ModelCheckpoint` callback is used to save the model during training. It monitors the performance of the model on the validation data and saves the model with the best performance based on a specified metric.
#
# Following setup ensures that the model with the highest validation AUC (`val_auc`) during training is saved to the file `best_model.keras`. Only the best model is saved, preventing overwriting with worse-performing models.

# %%
ckpt_cb = keras.callbacks.ModelCheckpoint(
    "best_model.keras",   # Filepath where the model will be saved.
    monitor="val_auc",    # Metric to monitor (validation AUC in this case).
    save_best_only=True,  # Save only the model with the best performance.
    save_weights_only=False,  # Save the entire model (not just the weights).
    mode="max",           # The model with the maximum 'val_auc' will be saved.
)

# %% [markdown]
# #| Training
#
# Follwing cell will train the prepared model. Notice that, `class_weight` is used in the training.

# %%
history = model.fit(
    training_ds,
    epochs=CFG.epochs,
    callbacks=[lr_cb, ckpt_cb],
    validation_data=validation_ds,
    verbose=CFG.verbose,
    class_weight=class_weights,
)
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727988969.025934      69 service.cc:145] XLA service 0x7b78e4056580 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1727988969.026034      69 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727989079.372208      69 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_11', 104 bytes spill stores, 132 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function '__cuda_sm3x_div_rn_noftz_f32_slowpath', 24 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1727989079.488434      69 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 18/19 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.4064 - auc: 0.4123 - loss: 0.7478 - precision: 0.2963 - recall: 0.5330
# I0000 00:00:1727989179.694845      68 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_11', 104 bytes spill stores, 132 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function '__cuda_sm3x_div_rn_noftz_f32_slowpath', 24 bytes spill stores, 24 bytes spill loads
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 283s 6s/step - accuracy: 0.4073 - auc: 0.4139 - loss: 0.7471 - precision: 0.2970 - recall: 0.5335 - val_accuracy: 0.3949 - val_auc: 0.3219 - val_loss: 0.7209 - val_precision: 0.1942 - val_recall: 0.3833 - learning_rate: 2.5000e-05
# Epoch 2/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 49s 789ms/step - accuracy: 0.5917 - auc: 0.6465 - loss: 0.6562 - precision: 0.4381 - recall: 0.6163 - val_accuracy: 0.7773 - val_auc: 0.7717 - val_loss: 0.5663 - val_precision: 0.6132 - val_recall: 0.5072 - learning_rate: 4.4333e-04
# Epoch 3/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 17s 754ms/step - accuracy: 0.7789 - auc: 0.8521 - loss: 0.4961 - precision: 0.6599 - recall: 0.7362 - val_accuracy: 0.8254 - val_auc: 0.8727 - val_loss: 0.4331 - val_precision: 0.6750 - val_recall: 0.7003 - learning_rate: 8.6167e-04
# Epoch 4/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 786ms/step - accuracy: 0.8243 - auc: 0.9029 - loss: 0.4168 - precision: 0.7063 - recall: 0.8294 - val_accuracy: 0.8697 - val_auc: 0.9340 - val_loss: 0.3569 - val_precision: 0.8447 - val_recall: 0.6427 - learning_rate: 0.0013
# Epoch 5/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 749ms/step - accuracy: 0.8308 - auc: 0.9177 - loss: 0.3881 - precision: 0.7170 - recall: 0.8416 - val_accuracy: 0.8752 - val_auc: 0.9460 - val_loss: 0.3495 - val_precision: 0.7224 - val_recall: 0.8847 - learning_rate: 9.6200e-04
# Epoch 6/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 698ms/step - accuracy: 0.8635 - auc: 0.9404 - loss: 0.3422 - precision: 0.7663 - recall: 0.8685 - val_accuracy: 0.8902 - val_auc: 0.9444 - val_loss: 0.3039 - val_precision: 0.8023 - val_recall: 0.7954 - learning_rate: 7.2350e-04
# Epoch 7/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 22s 770ms/step - accuracy: 0.8609 - auc: 0.9424 - loss: 0.3340 - precision: 0.7535 - recall: 0.8877 - val_accuracy: 0.8981 - val_auc: 0.9495 - val_loss: 0.2928 - val_precision: 0.8114 - val_recall: 0.8184 - learning_rate: 5.4462e-04
# Epoch 8/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 687ms/step - accuracy: 0.8717 - auc: 0.9514 - loss: 0.3113 - precision: 0.7729 - recall: 0.8892 - val_accuracy: 0.8910 - val_auc: 0.9473 - val_loss: 0.3012 - val_precision: 0.8317 - val_recall: 0.7550 - learning_rate: 4.1047e-04
# Epoch 9/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 17s 772ms/step - accuracy: 0.8800 - auc: 0.9568 - loss: 0.2968 - precision: 0.7908 - recall: 0.8859 - val_accuracy: 0.8957 - val_auc: 0.9521 - val_loss: 0.2906 - val_precision: 0.8063 - val_recall: 0.8156 - learning_rate: 3.0985e-04
# Epoch 10/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 17s 758ms/step - accuracy: 0.8797 - auc: 0.9565 - loss: 0.2970 - precision: 0.7812 - recall: 0.9037 - val_accuracy: 0.9021 - val_auc: 0.9529 - val_loss: 0.2903 - val_precision: 0.8123 - val_recall: 0.8357 - learning_rate: 2.3439e-04
# Epoch 11/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 17s 766ms/step - accuracy: 0.8905 - auc: 0.9615 - loss: 0.2826 - precision: 0.8021 - recall: 0.9061 - val_accuracy: 0.9060 - val_auc: 0.9554 - val_loss: 0.2838 - val_precision: 0.8132 - val_recall: 0.8530 - learning_rate: 1.7779e-04
# Epoch 12/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 17s 751ms/step - accuracy: 0.8923 - auc: 0.9653 - loss: 0.2715 - precision: 0.8077 - recall: 0.9004 - val_accuracy: 0.9060 - val_auc: 0.9568 - val_loss: 0.2850 - val_precision: 0.8413 - val_recall: 0.8098 - learning_rate: 1.3534e-04
# Epoch 13/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 708ms/step - accuracy: 0.8977 - auc: 0.9675 - loss: 0.2651 - precision: 0.8118 - recall: 0.9144 - val_accuracy: 0.9084 - val_auc: 0.9534 - val_loss: 0.2886 - val_precision: 0.8199 - val_recall: 0.8530 - learning_rate: 1.0351e-04
# Epoch 14/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 683ms/step - accuracy: 0.8926 - auc: 0.9657 - loss: 0.2693 - precision: 0.8064 - recall: 0.9034 - val_accuracy: 0.9060 - val_auc: 0.9553 - val_loss: 0.2863 - val_precision: 0.8413 - val_recall: 0.8098 - learning_rate: 7.9631e-05
# Epoch 15/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 698ms/step - accuracy: 0.8982 - auc: 0.9684 - loss: 0.2617 - precision: 0.8104 - recall: 0.9195 - val_accuracy: 0.9068 - val_auc: 0.9556 - val_loss: 0.2888 - val_precision: 0.8545 - val_recall: 0.7954 - learning_rate: 6.1723e-05
# Epoch 16/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 694ms/step - accuracy: 0.9019 - auc: 0.9727 - loss: 0.2492 - precision: 0.8246 - recall: 0.9086 - val_accuracy: 0.9155 - val_auc: 0.9555 - val_loss: 0.2875 - val_precision: 0.8550 - val_recall: 0.8329 - learning_rate: 4.8292e-05
# Epoch 17/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 691ms/step - accuracy: 0.9019 - auc: 0.9710 - loss: 0.2537 - precision: 0.8212 - recall: 0.9145 - val_accuracy: 0.9123 - val_auc: 0.9554 - val_loss: 0.2900 - val_precision: 0.8598 - val_recall: 0.8127 - learning_rate: 3.8219e-05
# Epoch 18/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 710ms/step - accuracy: 0.8957 - auc: 0.9687 - loss: 0.2608 - precision: 0.8082 - recall: 0.9136 - val_accuracy: 0.8997 - val_auc: 0.9538 - val_loss: 0.2911 - val_precision: 0.8438 - val_recall: 0.7781 - learning_rate: 3.0664e-05
# Epoch 19/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 694ms/step - accuracy: 0.9035 - auc: 0.9711 - loss: 0.2539 - precision: 0.8255 - recall: 0.9134 - val_accuracy: 0.9052 - val_auc: 0.9555 - val_loss: 0.2923 - val_precision: 0.8429 - val_recall: 0.8040 - learning_rate: 2.4998e-05
# Epoch 20/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 709ms/step - accuracy: 0.9142 - auc: 0.9741 - loss: 0.2427 - precision: 0.8425 - recall: 0.9230 - val_accuracy: 0.9021 - val_auc: 0.9543 - val_loss: 0.2944 - val_precision: 0.8452 - val_recall: 0.7867 - learning_rate: 2.0749e-05
# Epoch 21/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 691ms/step - accuracy: 0.9003 - auc: 0.9686 - loss: 0.2606 - precision: 0.8239 - recall: 0.9037 - val_accuracy: 0.9068 - val_auc: 0.9542 - val_loss: 0.2953 - val_precision: 0.8480 - val_recall: 0.8040 - learning_rate: 1.7562e-05
# Epoch 22/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 719ms/step - accuracy: 0.8980 - auc: 0.9733 - loss: 0.2464 - precision: 0.8157 - recall: 0.9090 - val_accuracy: 0.9021 - val_auc: 0.9541 - val_loss: 0.2973 - val_precision: 0.8517 - val_recall: 0.7781 - learning_rate: 1.5171e-05
# Epoch 23/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 685ms/step - accuracy: 0.9123 - auc: 0.9724 - loss: 0.2491 - precision: 0.8369 - recall: 0.9257 - val_accuracy: 0.9028 - val_auc: 0.9542 - val_loss: 0.2953 - val_precision: 0.8394 - val_recall: 0.7983 - learning_rate: 1.3378e-05
# Epoch 24/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 707ms/step - accuracy: 0.9019 - auc: 0.9723 - loss: 0.2498 - precision: 0.8193 - recall: 0.9174 - val_accuracy: 0.9021 - val_auc: 0.9545 - val_loss: 0.2961 - val_precision: 0.8452 - val_recall: 0.7867 - learning_rate: 1.2034e-05
# Epoch 25/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 692ms/step - accuracy: 0.8972 - auc: 0.9691 - loss: 0.2602 - precision: 0.8165 - recall: 0.9058 - val_accuracy: 0.9021 - val_auc: 0.9542 - val_loss: 0.2947 - val_precision: 0.8452 - val_recall: 0.7867 - learning_rate: 1.1025e-05
# Epoch 26/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 704ms/step - accuracy: 0.9088 - auc: 0.9747 - loss: 0.2418 - precision: 0.8311 - recall: 0.9224 - val_accuracy: 0.9028 - val_auc: 0.9539 - val_loss: 0.2976 - val_precision: 0.8478 - val_recall: 0.7867 - learning_rate: 1.0269e-05
# Epoch 27/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 679ms/step - accuracy: 0.9016 - auc: 0.9702 - loss: 0.2557 - precision: 0.8257 - recall: 0.9029 - val_accuracy: 0.9107 - val_auc: 0.9533 - val_loss: 0.2948 - val_precision: 0.8524 - val_recall: 0.8156 - learning_rate: 9.7018e-06
# Epoch 28/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 713ms/step - accuracy: 0.9031 - auc: 0.9711 - loss: 0.2525 - precision: 0.8305 - recall: 0.9038 - val_accuracy: 0.9052 - val_auc: 0.9544 - val_loss: 0.2968 - val_precision: 0.8558 - val_recall: 0.7867 - learning_rate: 9.2763e-06
# Epoch 29/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 687ms/step - accuracy: 0.9055 - auc: 0.9729 - loss: 0.2470 - precision: 0.8250 - recall: 0.9216 - val_accuracy: 0.9060 - val_auc: 0.9546 - val_loss: 0.2966 - val_precision: 0.8562 - val_recall: 0.7896 - learning_rate: 8.9572e-06
# Epoch 30/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 678ms/step - accuracy: 0.9026 - auc: 0.9701 - loss: 0.2557 - precision: 0.8265 - recall: 0.9077 - val_accuracy: 0.9076 - val_auc: 0.9541 - val_loss: 0.2974 - val_precision: 0.8571 - val_recall: 0.7954 - learning_rate: 8.7179e-06
# Epoch 31/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 689ms/step - accuracy: 0.9024 - auc: 0.9703 - loss: 0.2558 - precision: 0.8301 - recall: 0.8996 - val_accuracy: 0.9060 - val_auc: 0.9540 - val_loss: 0.2981 - val_precision: 0.8585 - val_recall: 0.7867 - learning_rate: 8.5384e-06
# Epoch 32/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 698ms/step - accuracy: 0.9071 - auc: 0.9740 - loss: 0.2417 - precision: 0.8208 - recall: 0.9333 - val_accuracy: 0.9068 - val_auc: 0.9537 - val_loss: 0.2949 - val_precision: 0.8545 - val_recall: 0.7954 - learning_rate: 8.4038e-06
# Epoch 33/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 686ms/step - accuracy: 0.9098 - auc: 0.9726 - loss: 0.2475 - precision: 0.8369 - recall: 0.9168 - val_accuracy: 0.9076 - val_auc: 0.9539 - val_loss: 0.2969 - val_precision: 0.8571 - val_recall: 0.7954 - learning_rate: 8.3029e-06
# Epoch 34/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 709ms/step - accuracy: 0.9006 - auc: 0.9727 - loss: 0.2478 - precision: 0.8212 - recall: 0.9091 - val_accuracy: 0.8981 - val_auc: 0.9541 - val_loss: 0.3008 - val_precision: 0.8539 - val_recall: 0.7579 - learning_rate: 8.2272e-06
# Epoch 35/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 684ms/step - accuracy: 0.9066 - auc: 0.9736 - loss: 0.2452 - precision: 0.8209 - recall: 0.9323 - val_accuracy: 0.9068 - val_auc: 0.9540 - val_loss: 0.3017 - val_precision: 0.8589 - val_recall: 0.7896 - learning_rate: 8.1704e-06
# Epoch 36/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 704ms/step - accuracy: 0.9055 - auc: 0.9728 - loss: 0.2479 - precision: 0.8318 - recall: 0.9095 - val_accuracy: 0.9123 - val_auc: 0.9540 - val_loss: 0.2993 - val_precision: 0.8598 - val_recall: 0.8127 - learning_rate: 8.1278e-06
# Epoch 37/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 695ms/step - accuracy: 0.9024 - auc: 0.9713 - loss: 0.2527 - precision: 0.8258 - recall: 0.9079 - val_accuracy: 0.9052 - val_auc: 0.9533 - val_loss: 0.3010 - val_precision: 0.8558 - val_recall: 0.7867 - learning_rate: 8.0958e-06
# Epoch 38/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 681ms/step - accuracy: 0.9068 - auc: 0.9750 - loss: 0.2398 - precision: 0.8270 - recall: 0.9216 - val_accuracy: 0.9013 - val_auc: 0.9536 - val_loss: 0.3032 - val_precision: 0.8535 - val_recall: 0.7723 - learning_rate: 8.0719e-06
# Epoch 39/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 703ms/step - accuracy: 0.9023 - auc: 0.9721 - loss: 0.2489 - precision: 0.8230 - recall: 0.9130 - val_accuracy: 0.9005 - val_auc: 0.9533 - val_loss: 0.3042 - val_precision: 0.8508 - val_recall: 0.7723 - learning_rate: 8.0539e-06
# Epoch 40/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 698ms/step - accuracy: 0.9137 - auc: 0.9785 - loss: 0.2292 - precision: 0.8356 - recall: 0.9323 - val_accuracy: 0.9084 - val_auc: 0.9540 - val_loss: 0.3017 - val_precision: 0.8598 - val_recall: 0.7954 - learning_rate: 8.0404e-06
# Epoch 41/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 703ms/step - accuracy: 0.9116 - auc: 0.9750 - loss: 0.2411 - precision: 0.8344 - recall: 0.9264 - val_accuracy: 0.8973 - val_auc: 0.9542 - val_loss: 0.3046 - val_precision: 0.8557 - val_recall: 0.7522 - learning_rate: 8.0303e-06
# Epoch 42/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 695ms/step - accuracy: 0.9121 - auc: 0.9732 - loss: 0.2463 - precision: 0.8400 - recall: 0.9199 - val_accuracy: 0.9028 - val_auc: 0.9540 - val_loss: 0.3044 - val_precision: 0.8567 - val_recall: 0.7752 - learning_rate: 8.0227e-06
# Epoch 43/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 712ms/step - accuracy: 0.9074 - auc: 0.9755 - loss: 0.2392 - precision: 0.8307 - recall: 0.9178 - val_accuracy: 0.9123 - val_auc: 0.9539 - val_loss: 0.3020 - val_precision: 0.8598 - val_recall: 0.8127 - learning_rate: 8.0171e-06
# Epoch 44/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 689ms/step - accuracy: 0.9042 - auc: 0.9721 - loss: 0.2494 - precision: 0.8273 - recall: 0.9127 - val_accuracy: 0.9005 - val_auc: 0.9544 - val_loss: 0.3060 - val_precision: 0.8553 - val_recall: 0.7666 - learning_rate: 8.0128e-06
# Epoch 45/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 716ms/step - accuracy: 0.9056 - auc: 0.9731 - loss: 0.2473 - precision: 0.8272 - recall: 0.9171 - val_accuracy: 0.9107 - val_auc: 0.9540 - val_loss: 0.3003 - val_precision: 0.8567 - val_recall: 0.8098 - learning_rate: 8.0096e-06
# Epoch 46/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 691ms/step - accuracy: 0.9042 - auc: 0.9745 - loss: 0.2422 - precision: 0.8231 - recall: 0.9181 - val_accuracy: 0.9028 - val_auc: 0.9536 - val_loss: 0.3032 - val_precision: 0.8567 - val_recall: 0.7752 - learning_rate: 8.0072e-06
# Epoch 47/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 711ms/step - accuracy: 0.9029 - auc: 0.9709 - loss: 0.2544 - precision: 0.8248 - recall: 0.9110 - val_accuracy: 0.9060 - val_auc: 0.9536 - val_loss: 0.3009 - val_precision: 0.8519 - val_recall: 0.7954 - learning_rate: 8.0054e-06
# Epoch 48/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 678ms/step - accuracy: 0.9019 - auc: 0.9731 - loss: 0.2468 - precision: 0.8246 - recall: 0.9056 - val_accuracy: 0.9076 - val_auc: 0.9530 - val_loss: 0.3024 - val_precision: 0.8571 - val_recall: 0.7954 - learning_rate: 8.0040e-06
# Epoch 49/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 703ms/step - accuracy: 0.9043 - auc: 0.9750 - loss: 0.2389 - precision: 0.8240 - recall: 0.9183 - val_accuracy: 0.9060 - val_auc: 0.9535 - val_loss: 0.3007 - val_precision: 0.8540 - val_recall: 0.7925 - learning_rate: 8.0030e-06
# Epoch 50/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 683ms/step - accuracy: 0.9073 - auc: 0.9755 - loss: 0.2385 - precision: 0.8312 - recall: 0.9154 - val_accuracy: 0.9115 - val_auc: 0.9531 - val_loss: 0.3007 - val_precision: 0.8529 - val_recall: 0.8184 - learning_rate: 8.0023e-06
# Epoch 51/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 693ms/step - accuracy: 0.9085 - auc: 0.9736 - loss: 0.2445 - precision: 0.8342 - recall: 0.9163 - val_accuracy: 0.9076 - val_auc: 0.9542 - val_loss: 0.3031 - val_precision: 0.8594 - val_recall: 0.7925 - learning_rate: 8.0017e-06
# Epoch 52/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 694ms/step - accuracy: 0.9056 - auc: 0.9746 - loss: 0.2417 - precision: 0.8258 - recall: 0.9198 - val_accuracy: 0.9028 - val_auc: 0.9537 - val_loss: 0.3039 - val_precision: 0.8544 - val_recall: 0.7781 - learning_rate: 8.0013e-06
# Epoch 53/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 700ms/step - accuracy: 0.9167 - auc: 0.9769 - loss: 0.2339 - precision: 0.8398 - recall: 0.9364 - val_accuracy: 0.9013 - val_auc: 0.9537 - val_loss: 0.3042 - val_precision: 0.8513 - val_recall: 0.7752 - learning_rate: 8.0010e-06
# Epoch 54/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 674ms/step - accuracy: 0.9095 - auc: 0.9732 - loss: 0.2457 - precision: 0.8326 - recall: 0.9188 - val_accuracy: 0.9092 - val_auc: 0.9540 - val_loss: 0.3044 - val_precision: 0.8602 - val_recall: 0.7983 - learning_rate: 8.0007e-06
# Epoch 55/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 688ms/step - accuracy: 0.8986 - auc: 0.9691 - loss: 0.2591 - precision: 0.8150 - recall: 0.9115 - val_accuracy: 0.9068 - val_auc: 0.9534 - val_loss: 0.3046 - val_precision: 0.8567 - val_recall: 0.7925 - learning_rate: 8.0005e-06
# Epoch 56/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 676ms/step - accuracy: 0.9061 - auc: 0.9736 - loss: 0.2435 - precision: 0.8217 - recall: 0.9286 - val_accuracy: 0.9005 - val_auc: 0.9540 - val_loss: 0.3083 - val_precision: 0.8576 - val_recall: 0.7637 - learning_rate: 8.0004e-06
# Epoch 57/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 710ms/step - accuracy: 0.9057 - auc: 0.9730 - loss: 0.2452 - precision: 0.8281 - recall: 0.9159 - val_accuracy: 0.8981 - val_auc: 0.9544 - val_loss: 0.3066 - val_precision: 0.8562 - val_recall: 0.7550 - learning_rate: 8.0003e-06
# Epoch 58/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 699ms/step - accuracy: 0.9117 - auc: 0.9755 - loss: 0.2381 - precision: 0.8335 - recall: 0.9289 - val_accuracy: 0.9076 - val_auc: 0.9538 - val_loss: 0.3028 - val_precision: 0.8594 - val_recall: 0.7925 - learning_rate: 8.0002e-06
# Epoch 59/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 690ms/step - accuracy: 0.9169 - auc: 0.9781 - loss: 0.2305 - precision: 0.8466 - recall: 0.9262 - val_accuracy: 0.8934 - val_auc: 0.9541 - val_loss: 0.3065 - val_precision: 0.8510 - val_recall: 0.7406 - learning_rate: 8.0002e-06
# Epoch 60/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 689ms/step - accuracy: 0.9089 - auc: 0.9758 - loss: 0.2371 - precision: 0.8328 - recall: 0.9209 - val_accuracy: 0.9028 - val_auc: 0.9535 - val_loss: 0.3057 - val_precision: 0.8567 - val_recall: 0.7752 - learning_rate: 8.0001e-06
# Epoch 61/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 687ms/step - accuracy: 0.9061 - auc: 0.9731 - loss: 0.2475 - precision: 0.8283 - recall: 0.9177 - val_accuracy: 0.8997 - val_auc: 0.9533 - val_loss: 0.3093 - val_precision: 0.8548 - val_recall: 0.7637 - learning_rate: 8.0001e-06
# Epoch 62/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 683ms/step - accuracy: 0.9094 - auc: 0.9743 - loss: 0.2424 - precision: 0.8306 - recall: 0.9255 - val_accuracy: 0.9005 - val_auc: 0.9535 - val_loss: 0.3119 - val_precision: 0.8576 - val_recall: 0.7637 - learning_rate: 8.0001e-06
# Epoch 63/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 698ms/step - accuracy: 0.9135 - auc: 0.9767 - loss: 0.2344 - precision: 0.8391 - recall: 0.9257 - val_accuracy: 0.8965 - val_auc: 0.9537 - val_loss: 0.3101 - val_precision: 0.8553 - val_recall: 0.7493 - learning_rate: 8.0001e-06
# Epoch 64/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 675ms/step - accuracy: 0.9195 - auc: 0.9780 - loss: 0.2305 - precision: 0.8510 - recall: 0.9285 - val_accuracy: 0.8997 - val_auc: 0.9533 - val_loss: 0.3088 - val_precision: 0.8548 - val_recall: 0.7637 - learning_rate: 8.0000e-06
# Epoch 65/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 692ms/step - accuracy: 0.9132 - auc: 0.9741 - loss: 0.2439 - precision: 0.8413 - recall: 0.9217 - val_accuracy: 0.8957 - val_auc: 0.9535 - val_loss: 0.3108 - val_precision: 0.8525 - val_recall: 0.7493 - learning_rate: 8.0000e-06
# Epoch 66/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 682ms/step - accuracy: 0.9096 - auc: 0.9762 - loss: 0.2360 - precision: 0.8360 - recall: 0.9161 - val_accuracy: 0.8973 - val_auc: 0.9534 - val_loss: 0.3119 - val_precision: 0.8581 - val_recall: 0.7493 - learning_rate: 8.0000e-06
# Epoch 67/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 690ms/step - accuracy: 0.9032 - auc: 0.9740 - loss: 0.2437 - precision: 0.8200 - recall: 0.9201 - val_accuracy: 0.8973 - val_auc: 0.9539 - val_loss: 0.3151 - val_precision: 0.8581 - val_recall: 0.7493 - learning_rate: 8.0000e-06
# Epoch 68/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 686ms/step - accuracy: 0.9151 - auc: 0.9797 - loss: 0.2245 - precision: 0.8402 - recall: 0.9295 - val_accuracy: 0.8949 - val_auc: 0.9539 - val_loss: 0.3149 - val_precision: 0.8615 - val_recall: 0.7349 - learning_rate: 8.0000e-06
# Epoch 69/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 687ms/step - accuracy: 0.9068 - auc: 0.9741 - loss: 0.2436 - precision: 0.8272 - recall: 0.9224 - val_accuracy: 0.8981 - val_auc: 0.9535 - val_loss: 0.3112 - val_precision: 0.8586 - val_recall: 0.7522 - learning_rate: 8.0000e-06
# Epoch 70/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 678ms/step - accuracy: 0.9142 - auc: 0.9752 - loss: 0.2392 - precision: 0.8408 - recall: 0.9266 - val_accuracy: 0.8997 - val_auc: 0.9534 - val_loss: 0.3135 - val_precision: 0.8548 - val_recall: 0.7637 - learning_rate: 8.0000e-06
# Epoch 71/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 693ms/step - accuracy: 0.9184 - auc: 0.9756 - loss: 0.2372 - precision: 0.8462 - recall: 0.9320 - val_accuracy: 0.9005 - val_auc: 0.9533 - val_loss: 0.3131 - val_precision: 0.8576 - val_recall: 0.7637 - learning_rate: 8.0000e-06
# Epoch 72/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 682ms/step - accuracy: 0.9073 - auc: 0.9733 - loss: 0.2452 - precision: 0.8362 - recall: 0.9085 - val_accuracy: 0.8957 - val_auc: 0.9535 - val_loss: 0.3152 - val_precision: 0.8571 - val_recall: 0.7435 - learning_rate: 8.0000e-06
# Epoch 73/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 688ms/step - accuracy: 0.9138 - auc: 0.9793 - loss: 0.2262 - precision: 0.8326 - recall: 0.9381 - val_accuracy: 0.9044 - val_auc: 0.9529 - val_loss: 0.3121 - val_precision: 0.8576 - val_recall: 0.7810 - learning_rate: 8.0000e-06
# Epoch 74/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 689ms/step - accuracy: 0.9167 - auc: 0.9769 - loss: 0.2339 - precision: 0.8419 - recall: 0.9330 - val_accuracy: 0.9044 - val_auc: 0.9530 - val_loss: 0.3123 - val_precision: 0.8576 - val_recall: 0.7810 - learning_rate: 8.0000e-06
# Epoch 75/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 689ms/step - accuracy: 0.9069 - auc: 0.9732 - loss: 0.2452 - precision: 0.8341 - recall: 0.9106 - val_accuracy: 0.8973 - val_auc: 0.9530 - val_loss: 0.3136 - val_precision: 0.8557 - val_recall: 0.7522 - learning_rate: 8.0000e-06
# Epoch 76/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 703ms/step - accuracy: 0.9115 - auc: 0.9771 - loss: 0.2338 - precision: 0.8387 - recall: 0.9197 - val_accuracy: 0.8981 - val_auc: 0.9537 - val_loss: 0.3126 - val_precision: 0.8586 - val_recall: 0.7522 - learning_rate: 8.0000e-06
# Epoch 77/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 685ms/step - accuracy: 0.9133 - auc: 0.9789 - loss: 0.2268 - precision: 0.8345 - recall: 0.9329 - val_accuracy: 0.9044 - val_auc: 0.9531 - val_loss: 0.3114 - val_precision: 0.8576 - val_recall: 0.7810 - learning_rate: 8.0000e-06
# Epoch 78/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 710ms/step - accuracy: 0.9082 - auc: 0.9780 - loss: 0.2305 - precision: 0.8304 - recall: 0.9200 - val_accuracy: 0.8973 - val_auc: 0.9530 - val_loss: 0.3148 - val_precision: 0.8557 - val_recall: 0.7522 - learning_rate: 8.0000e-06
# Epoch 79/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 697ms/step - accuracy: 0.9134 - auc: 0.9753 - loss: 0.2397 - precision: 0.8411 - recall: 0.9232 - val_accuracy: 0.8934 - val_auc: 0.9532 - val_loss: 0.3169 - val_precision: 0.8533 - val_recall: 0.7378 - learning_rate: 8.0000e-06
# Epoch 80/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 695ms/step - accuracy: 0.9114 - auc: 0.9746 - loss: 0.2408 - precision: 0.8398 - recall: 0.9186 - val_accuracy: 0.8989 - val_auc: 0.9528 - val_loss: 0.3126 - val_precision: 0.8521 - val_recall: 0.7637 - learning_rate: 8.0000e-06
# Epoch 81/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 695ms/step - accuracy: 0.9161 - auc: 0.9787 - loss: 0.2283 - precision: 0.8454 - recall: 0.9255 - val_accuracy: 0.8973 - val_auc: 0.9523 - val_loss: 0.3173 - val_precision: 0.8557 - val_recall: 0.7522 - learning_rate: 8.0000e-06
# Epoch 82/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 705ms/step - accuracy: 0.9165 - auc: 0.9747 - loss: 0.2409 - precision: 0.8461 - recall: 0.9264 - val_accuracy: 0.8973 - val_auc: 0.9527 - val_loss: 0.3183 - val_precision: 0.8581 - val_recall: 0.7493 - learning_rate: 8.0000e-06
# Epoch 83/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 686ms/step - accuracy: 0.9166 - auc: 0.9790 - loss: 0.2263 - precision: 0.8469 - recall: 0.9257 - val_accuracy: 0.9036 - val_auc: 0.9526 - val_loss: 0.3164 - val_precision: 0.8689 - val_recall: 0.7637 - learning_rate: 8.0000e-06
# Epoch 84/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 712ms/step - accuracy: 0.9207 - auc: 0.9787 - loss: 0.2271 - precision: 0.8457 - recall: 0.9411 - val_accuracy: 0.8989 - val_auc: 0.9531 - val_loss: 0.3252 - val_precision: 0.8638 - val_recall: 0.7493 - learning_rate: 8.0000e-06
# Epoch 85/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 689ms/step - accuracy: 0.9128 - auc: 0.9781 - loss: 0.2275 - precision: 0.8350 - recall: 0.9298 - val_accuracy: 0.8965 - val_auc: 0.9525 - val_loss: 0.3169 - val_precision: 0.8553 - val_recall: 0.7493 - learning_rate: 8.0000e-06
# Epoch 86/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 689ms/step - accuracy: 0.9078 - auc: 0.9736 - loss: 0.2434 - precision: 0.8351 - recall: 0.9124 - val_accuracy: 0.8973 - val_auc: 0.9529 - val_loss: 0.3184 - val_precision: 0.8581 - val_recall: 0.7493 - learning_rate: 8.0000e-06
# Epoch 87/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 687ms/step - accuracy: 0.9098 - auc: 0.9749 - loss: 0.2402 - precision: 0.8378 - recall: 0.9155 - val_accuracy: 0.8926 - val_auc: 0.9529 - val_loss: 0.3174 - val_precision: 0.8505 - val_recall: 0.7378 - learning_rate: 8.0000e-06
# Epoch 88/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 713ms/step - accuracy: 0.9118 - auc: 0.9776 - loss: 0.2316 - precision: 0.8403 - recall: 0.9181 - val_accuracy: 0.8965 - val_auc: 0.9525 - val_loss: 0.3177 - val_precision: 0.8529 - val_recall: 0.7522 - learning_rate: 8.0000e-06
# Epoch 89/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 692ms/step - accuracy: 0.9113 - auc: 0.9773 - loss: 0.2325 - precision: 0.8384 - recall: 0.9191 - val_accuracy: 0.8957 - val_auc: 0.9525 - val_loss: 0.3172 - val_precision: 0.8502 - val_recall: 0.7522 - learning_rate: 8.0000e-06
# Epoch 90/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 710ms/step - accuracy: 0.9103 - auc: 0.9764 - loss: 0.2348 - precision: 0.8313 - recall: 0.9271 - val_accuracy: 0.8989 - val_auc: 0.9520 - val_loss: 0.3159 - val_precision: 0.8521 - val_recall: 0.7637 - learning_rate: 8.0000e-06
# Epoch 91/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 695ms/step - accuracy: 0.9172 - auc: 0.9789 - loss: 0.2250 - precision: 0.8389 - recall: 0.9395 - val_accuracy: 0.8926 - val_auc: 0.9524 - val_loss: 0.3202 - val_precision: 0.8528 - val_recall: 0.7349 - learning_rate: 8.0000e-06
# Epoch 92/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 698ms/step - accuracy: 0.9165 - auc: 0.9782 - loss: 0.2276 - precision: 0.8454 - recall: 0.9277 - val_accuracy: 0.8957 - val_auc: 0.9520 - val_loss: 0.3196 - val_precision: 0.8502 - val_recall: 0.7522 - learning_rate: 8.0000e-06
# Epoch 93/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 682ms/step - accuracy: 0.9109 - auc: 0.9773 - loss: 0.2318 - precision: 0.8365 - recall: 0.9219 - val_accuracy: 0.8918 - val_auc: 0.9525 - val_loss: 0.3218 - val_precision: 0.8500 - val_recall: 0.7349 - learning_rate: 8.0000e-06
# Epoch 94/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 696ms/step - accuracy: 0.9066 - auc: 0.9741 - loss: 0.2419 - precision: 0.8311 - recall: 0.9137 - val_accuracy: 0.8910 - val_auc: 0.9521 - val_loss: 0.3200 - val_precision: 0.8472 - val_recall: 0.7349 - learning_rate: 8.0000e-06
# Epoch 95/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 685ms/step - accuracy: 0.9123 - auc: 0.9776 - loss: 0.2305 - precision: 0.8407 - recall: 0.9205 - val_accuracy: 0.8910 - val_auc: 0.9524 - val_loss: 0.3229 - val_precision: 0.8616 - val_recall: 0.7176 - learning_rate: 8.0000e-06
# Epoch 96/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 690ms/step - accuracy: 0.9134 - auc: 0.9781 - loss: 0.2281 - precision: 0.8389 - recall: 0.9265 - val_accuracy: 0.8989 - val_auc: 0.9523 - val_loss: 0.3208 - val_precision: 0.8614 - val_recall: 0.7522 - learning_rate: 8.0000e-06
# Epoch 97/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 699ms/step - accuracy: 0.9134 - auc: 0.9780 - loss: 0.2297 - precision: 0.8421 - recall: 0.9207 - val_accuracy: 0.8957 - val_auc: 0.9530 - val_loss: 0.3225 - val_precision: 0.8644 - val_recall: 0.7349 - learning_rate: 8.0000e-06
# Epoch 98/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 687ms/step - accuracy: 0.9192 - auc: 0.9789 - loss: 0.2255 - precision: 0.8496 - recall: 0.9299 - val_accuracy: 0.8965 - val_auc: 0.9524 - val_loss: 0.3204 - val_precision: 0.8529 - val_recall: 0.7522 - learning_rate: 8.0000e-06
# Epoch 99/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 703ms/step - accuracy: 0.9110 - auc: 0.9795 - loss: 0.2236 - precision: 0.8363 - recall: 0.9217 - val_accuracy: 0.8997 - val_auc: 0.9527 - val_loss: 0.3204 - val_precision: 0.8642 - val_recall: 0.7522 - learning_rate: 8.0000e-06
# Epoch 100/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 688ms/step - accuracy: 0.9204 - auc: 0.9781 - loss: 0.2308 - precision: 0.8526 - recall: 0.9284 - val_accuracy: 0.8902 - val_auc: 0.9531 - val_loss: 0.3264 - val_precision: 0.8636 - val_recall: 0.7118 - learning_rate: 8.0000e-06
# Epoch 101/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 694ms/step - accuracy: 0.9101 - auc: 0.9764 - loss: 0.2341 - precision: 0.8385 - recall: 0.9156 - val_accuracy: 0.8981 - val_auc: 0.9528 - val_loss: 0.3213 - val_precision: 0.8609 - val_recall: 0.7493 - learning_rate: 8.0000e-06
# Epoch 102/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 700ms/step - accuracy: 0.9233 - auc: 0.9797 - loss: 0.2231 - precision: 0.8578 - recall: 0.9308 - val_accuracy: 0.8957 - val_auc: 0.9531 - val_loss: 0.3229 - val_precision: 0.8644 - val_recall: 0.7349 - learning_rate: 8.0000e-06
# Epoch 103/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 711ms/step - accuracy: 0.9108 - auc: 0.9759 - loss: 0.2372 - precision: 0.8392 - recall: 0.9162 - val_accuracy: 0.8839 - val_auc: 0.9532 - val_loss: 0.3228 - val_precision: 0.8546 - val_recall: 0.6945 - learning_rate: 8.0000e-06
# Epoch 104/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 712ms/step - accuracy: 0.9155 - auc: 0.9772 - loss: 0.2323 - precision: 0.8419 - recall: 0.9285 - val_accuracy: 0.8839 - val_auc: 0.9532 - val_loss: 0.3212 - val_precision: 0.8546 - val_recall: 0.6945 - learning_rate: 8.0000e-06
# Epoch 105/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 719ms/step - accuracy: 0.9061 - auc: 0.9743 - loss: 0.2406 - precision: 0.8300 - recall: 0.9153 - val_accuracy: 0.8942 - val_auc: 0.9526 - val_loss: 0.3205 - val_precision: 0.8586 - val_recall: 0.7349 - learning_rate: 8.0000e-06
# Epoch 106/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 695ms/step - accuracy: 0.9125 - auc: 0.9771 - loss: 0.2333 - precision: 0.8437 - recall: 0.9152 - val_accuracy: 0.8942 - val_auc: 0.9528 - val_loss: 0.3205 - val_precision: 0.8586 - val_recall: 0.7349 - learning_rate: 8.0000e-06
# Epoch 107/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 703ms/step - accuracy: 0.9173 - auc: 0.9785 - loss: 0.2276 - precision: 0.8426 - recall: 0.9337 - val_accuracy: 0.8973 - val_auc: 0.9535 - val_loss: 0.3234 - val_precision: 0.8703 - val_recall: 0.7349 - learning_rate: 8.0000e-06
# Epoch 108/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 698ms/step - accuracy: 0.9062 - auc: 0.9753 - loss: 0.2377 - precision: 0.8343 - recall: 0.9079 - val_accuracy: 0.9013 - val_auc: 0.9530 - val_loss: 0.3186 - val_precision: 0.8675 - val_recall: 0.7550 - learning_rate: 8.0000e-06
# Epoch 109/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 725ms/step - accuracy: 0.9098 - auc: 0.9776 - loss: 0.2315 - precision: 0.8314 - recall: 0.9253 - val_accuracy: 0.8965 - val_auc: 0.9530 - val_loss: 0.3268 - val_precision: 0.8673 - val_recall: 0.7349 - learning_rate: 8.0000e-06
# Epoch 110/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 697ms/step - accuracy: 0.9139 - auc: 0.9785 - loss: 0.2279 - precision: 0.8488 - recall: 0.9126 - val_accuracy: 0.8965 - val_auc: 0.9529 - val_loss: 0.3253 - val_precision: 0.8673 - val_recall: 0.7349 - learning_rate: 8.0000e-06
# Epoch 111/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 726ms/step - accuracy: 0.9106 - auc: 0.9769 - loss: 0.2340 - precision: 0.8343 - recall: 0.9233 - val_accuracy: 0.8965 - val_auc: 0.9528 - val_loss: 0.3254 - val_precision: 0.8649 - val_recall: 0.7378 - learning_rate: 8.0000e-06
# Epoch 112/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 696ms/step - accuracy: 0.9202 - auc: 0.9772 - loss: 0.2315 - precision: 0.8535 - recall: 0.9275 - val_accuracy: 0.8949 - val_auc: 0.9522 - val_loss: 0.3269 - val_precision: 0.8615 - val_recall: 0.7349 - learning_rate: 8.0000e-06
# Epoch 113/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 695ms/step - accuracy: 0.9123 - auc: 0.9789 - loss: 0.2263 - precision: 0.8463 - recall: 0.9113 - val_accuracy: 0.8942 - val_auc: 0.9522 - val_loss: 0.3224 - val_precision: 0.8562 - val_recall: 0.7378 - learning_rate: 8.0000e-06
# Epoch 114/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 711ms/step - accuracy: 0.9153 - auc: 0.9777 - loss: 0.2310 - precision: 0.8494 - recall: 0.9170 - val_accuracy: 0.8997 - val_auc: 0.9516 - val_loss: 0.3219 - val_precision: 0.8618 - val_recall: 0.7550 - learning_rate: 8.0000e-06
# Epoch 115/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 690ms/step - accuracy: 0.9127 - auc: 0.9777 - loss: 0.2297 - precision: 0.8430 - recall: 0.9169 - val_accuracy: 0.8957 - val_auc: 0.9525 - val_loss: 0.3221 - val_precision: 0.8620 - val_recall: 0.7378 - learning_rate: 8.0000e-06
# Epoch 116/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 699ms/step - accuracy: 0.9150 - auc: 0.9802 - loss: 0.2219 - precision: 0.8466 - recall: 0.9201 - val_accuracy: 0.9021 - val_auc: 0.9519 - val_loss: 0.3209 - val_precision: 0.8632 - val_recall: 0.7637 - learning_rate: 8.0000e-06
# Epoch 117/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 693ms/step - accuracy: 0.9176 - auc: 0.9798 - loss: 0.2226 - precision: 0.8502 - recall: 0.9225 - val_accuracy: 0.9005 - val_auc: 0.9519 - val_loss: 0.3220 - val_precision: 0.8647 - val_recall: 0.7550 - learning_rate: 8.0000e-06
# Epoch 118/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 696ms/step - accuracy: 0.9089 - auc: 0.9759 - loss: 0.2359 - precision: 0.8361 - recall: 0.9142 - val_accuracy: 0.9005 - val_auc: 0.9521 - val_loss: 0.3213 - val_precision: 0.8576 - val_recall: 0.7637 - learning_rate: 8.0000e-06
# Epoch 119/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 690ms/step - accuracy: 0.9112 - auc: 0.9789 - loss: 0.2257 - precision: 0.8350 - recall: 0.9250 - val_accuracy: 0.9005 - val_auc: 0.9526 - val_loss: 0.3235 - val_precision: 0.8647 - val_recall: 0.7550 - learning_rate: 8.0000e-06
# Epoch 120/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 698ms/step - accuracy: 0.9168 - auc: 0.9793 - loss: 0.2245 - precision: 0.8436 - recall: 0.9263 - val_accuracy: 0.8942 - val_auc: 0.9523 - val_loss: 0.3242 - val_precision: 0.8610 - val_recall: 0.7320 - learning_rate: 8.0000e-06
# Epoch 121/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 689ms/step - accuracy: 0.9145 - auc: 0.9761 - loss: 0.2362 - precision: 0.8498 - recall: 0.9127 - val_accuracy: 0.8981 - val_auc: 0.9519 - val_loss: 0.3237 - val_precision: 0.8609 - val_recall: 0.7493 - learning_rate: 8.0000e-06
# Epoch 122/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 701ms/step - accuracy: 0.9117 - auc: 0.9785 - loss: 0.2270 - precision: 0.8400 - recall: 0.9181 - val_accuracy: 0.8855 - val_auc: 0.9524 - val_loss: 0.3268 - val_precision: 0.8582 - val_recall: 0.6974 - learning_rate: 8.0000e-06
# Epoch 123/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 697ms/step - accuracy: 0.9136 - auc: 0.9769 - loss: 0.2325 - precision: 0.8362 - recall: 0.9313 - val_accuracy: 0.8886 - val_auc: 0.9521 - val_loss: 0.3271 - val_precision: 0.8527 - val_recall: 0.7176 - learning_rate: 8.0000e-06
# Epoch 124/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 693ms/step - accuracy: 0.9230 - auc: 0.9808 - loss: 0.2180 - precision: 0.8538 - recall: 0.9361 - val_accuracy: 0.8902 - val_auc: 0.9519 - val_loss: 0.3235 - val_precision: 0.8586 - val_recall: 0.7176 - learning_rate: 8.0000e-06
# Epoch 125/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 695ms/step - accuracy: 0.9234 - auc: 0.9805 - loss: 0.2216 - precision: 0.8600 - recall: 0.9288 - val_accuracy: 0.8855 - val_auc: 0.9525 - val_loss: 0.3261 - val_precision: 0.8582 - val_recall: 0.6974 - learning_rate: 8.0000e-06
# Epoch 126/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 691ms/step - accuracy: 0.9207 - auc: 0.9789 - loss: 0.2255 - precision: 0.8546 - recall: 0.9273 - val_accuracy: 0.8799 - val_auc: 0.9524 - val_loss: 0.3292 - val_precision: 0.8571 - val_recall: 0.6744 - learning_rate: 8.0000e-06
# Epoch 127/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 680ms/step - accuracy: 0.9051 - auc: 0.9749 - loss: 0.2398 - precision: 0.8260 - recall: 0.9175 - val_accuracy: 0.8902 - val_auc: 0.9516 - val_loss: 0.3272 - val_precision: 0.8611 - val_recall: 0.7147 - learning_rate: 8.0000e-06
# Epoch 128/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 724ms/step - accuracy: 0.9139 - auc: 0.9787 - loss: 0.2259 - precision: 0.8426 - recall: 0.9219 - val_accuracy: 0.8918 - val_auc: 0.9516 - val_loss: 0.3316 - val_precision: 0.8671 - val_recall: 0.7147 - learning_rate: 8.0000e-06
# Epoch 129/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 681ms/step - accuracy: 0.9247 - auc: 0.9817 - loss: 0.2152 - precision: 0.8586 - recall: 0.9357 - val_accuracy: 0.8902 - val_auc: 0.9520 - val_loss: 0.3299 - val_precision: 0.8611 - val_recall: 0.7147 - learning_rate: 8.0000e-06
# Epoch 130/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 721ms/step - accuracy: 0.9236 - auc: 0.9806 - loss: 0.2190 - precision: 0.8573 - recall: 0.9330 - val_accuracy: 0.8918 - val_auc: 0.9517 - val_loss: 0.3324 - val_precision: 0.8671 - val_recall: 0.7147 - learning_rate: 8.0000e-06
# Epoch 131/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 685ms/step - accuracy: 0.9194 - auc: 0.9795 - loss: 0.2240 - precision: 0.8534 - recall: 0.9248 - val_accuracy: 0.9052 - val_auc: 0.9514 - val_loss: 0.3258 - val_precision: 0.8697 - val_recall: 0.7695 - learning_rate: 8.0000e-06
# Epoch 132/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 694ms/step - accuracy: 0.9168 - auc: 0.9779 - loss: 0.2289 - precision: 0.8468 - recall: 0.9256 - val_accuracy: 0.8855 - val_auc: 0.9514 - val_loss: 0.3296 - val_precision: 0.8582 - val_recall: 0.6974 - learning_rate: 8.0000e-06
# Epoch 133/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 700ms/step - accuracy: 0.9180 - auc: 0.9779 - loss: 0.2299 - precision: 0.8496 - recall: 0.9258 - val_accuracy: 0.8815 - val_auc: 0.9518 - val_loss: 0.3338 - val_precision: 0.8608 - val_recall: 0.6772 - learning_rate: 8.0000e-06
# Epoch 134/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 707ms/step - accuracy: 0.9195 - auc: 0.9805 - loss: 0.2209 - precision: 0.8513 - recall: 0.9277 - val_accuracy: 0.8799 - val_auc: 0.9512 - val_loss: 0.3350 - val_precision: 0.8545 - val_recall: 0.6772 - learning_rate: 8.0000e-06
# Epoch 135/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 702ms/step - accuracy: 0.9174 - auc: 0.9795 - loss: 0.2229 - precision: 0.8454 - recall: 0.9291 - val_accuracy: 0.8855 - val_auc: 0.9509 - val_loss: 0.3345 - val_precision: 0.8582 - val_recall: 0.6974 - learning_rate: 8.0000e-06
# Epoch 136/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 698ms/step - accuracy: 0.9139 - auc: 0.9762 - loss: 0.2341 - precision: 0.8419 - recall: 0.9236 - val_accuracy: 0.8839 - val_auc: 0.9507 - val_loss: 0.3336 - val_precision: 0.8597 - val_recall: 0.6888 - learning_rate: 8.0000e-06
# Epoch 137/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 692ms/step - accuracy: 0.9160 - auc: 0.9806 - loss: 0.2201 - precision: 0.8356 - recall: 0.9368 - val_accuracy: 0.8815 - val_auc: 0.9512 - val_loss: 0.3342 - val_precision: 0.8608 - val_recall: 0.6772 - learning_rate: 8.0000e-06
# Epoch 138/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 702ms/step - accuracy: 0.9195 - auc: 0.9812 - loss: 0.2166 - precision: 0.8499 - recall: 0.9306 - val_accuracy: 0.8863 - val_auc: 0.9516 - val_loss: 0.3316 - val_precision: 0.8612 - val_recall: 0.6974 - learning_rate: 8.0000e-06
# Epoch 139/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 697ms/step - accuracy: 0.9160 - auc: 0.9782 - loss: 0.2286 - precision: 0.8475 - recall: 0.9222 - val_accuracy: 0.8799 - val_auc: 0.9518 - val_loss: 0.3362 - val_precision: 0.8571 - val_recall: 0.6744 - learning_rate: 8.0000e-06
# Epoch 140/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 702ms/step - accuracy: 0.9141 - auc: 0.9779 - loss: 0.2302 - precision: 0.8412 - recall: 0.9256 - val_accuracy: 0.8807 - val_auc: 0.9519 - val_loss: 0.3343 - val_precision: 0.8577 - val_recall: 0.6772 - learning_rate: 8.0000e-06
# Epoch 141/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 700ms/step - accuracy: 0.9163 - auc: 0.9803 - loss: 0.2203 - precision: 0.8470 - recall: 0.9245 - val_accuracy: 0.8863 - val_auc: 0.9518 - val_loss: 0.3338 - val_precision: 0.8612 - val_recall: 0.6974 - learning_rate: 8.0000e-06
# Epoch 142/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 703ms/step - accuracy: 0.9131 - auc: 0.9767 - loss: 0.2329 - precision: 0.8467 - recall: 0.9134 - val_accuracy: 0.8965 - val_auc: 0.9519 - val_loss: 0.3316 - val_precision: 0.8649 - val_recall: 0.7378 - learning_rate: 8.0000e-06
# Epoch 143/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 700ms/step - accuracy: 0.9135 - auc: 0.9781 - loss: 0.2288 - precision: 0.8423 - recall: 0.9213 - val_accuracy: 0.8918 - val_auc: 0.9508 - val_loss: 0.3321 - val_precision: 0.8621 - val_recall: 0.7205 - learning_rate: 8.0000e-06
# Epoch 144/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 705ms/step - accuracy: 0.9210 - auc: 0.9789 - loss: 0.2267 - precision: 0.8548 - recall: 0.9275 - val_accuracy: 0.8855 - val_auc: 0.9508 - val_loss: 0.3337 - val_precision: 0.8607 - val_recall: 0.6945 - learning_rate: 8.0000e-06
# Epoch 145/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 682ms/step - accuracy: 0.9195 - auc: 0.9803 - loss: 0.2198 - precision: 0.8467 - recall: 0.9346 - val_accuracy: 0.8855 - val_auc: 0.9511 - val_loss: 0.3380 - val_precision: 0.8607 - val_recall: 0.6945 - learning_rate: 8.0000e-06
# Epoch 146/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 708ms/step - accuracy: 0.9169 - auc: 0.9771 - loss: 0.2314 - precision: 0.8503 - recall: 0.9191 - val_accuracy: 0.8847 - val_auc: 0.9512 - val_loss: 0.3355 - val_precision: 0.8577 - val_recall: 0.6945 - learning_rate: 8.0000e-06
# Epoch 147/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 688ms/step - accuracy: 0.9197 - auc: 0.9810 - loss: 0.2191 - precision: 0.8515 - recall: 0.9285 - val_accuracy: 0.8807 - val_auc: 0.9522 - val_loss: 0.3372 - val_precision: 0.8603 - val_recall: 0.6744 - learning_rate: 8.0000e-06
# Epoch 148/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 728ms/step - accuracy: 0.9150 - auc: 0.9783 - loss: 0.2261 - precision: 0.8455 - recall: 0.9206 - val_accuracy: 0.8926 - val_auc: 0.9517 - val_loss: 0.3348 - val_precision: 0.8676 - val_recall: 0.7176 - learning_rate: 8.0000e-06
# Epoch 149/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 687ms/step - accuracy: 0.9170 - auc: 0.9770 - loss: 0.2308 - precision: 0.8465 - recall: 0.9272 - val_accuracy: 0.8886 - val_auc: 0.9510 - val_loss: 0.3353 - val_precision: 0.8627 - val_recall: 0.7061 - learning_rate: 8.0000e-06
# Epoch 150/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 711ms/step - accuracy: 0.9129 - auc: 0.9774 - loss: 0.2319 - precision: 0.8378 - recall: 0.9256 - val_accuracy: 0.8863 - val_auc: 0.9513 - val_loss: 0.3366 - val_precision: 0.8638 - val_recall: 0.6945 - learning_rate: 8.0000e-06
# Epoch 151/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 694ms/step - accuracy: 0.9190 - auc: 0.9787 - loss: 0.2253 - precision: 0.8499 - recall: 0.9293 - val_accuracy: 0.8989 - val_auc: 0.9515 - val_loss: 0.3336 - val_precision: 0.8687 - val_recall: 0.7435 - learning_rate: 8.0000e-06
# Epoch 152/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 718ms/step - accuracy: 0.9144 - auc: 0.9767 - loss: 0.2336 - precision: 0.8417 - recall: 0.9248 - val_accuracy: 0.8799 - val_auc: 0.9519 - val_loss: 0.3377 - val_precision: 0.8571 - val_recall: 0.6744 - learning_rate: 8.0000e-06
# Epoch 153/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 693ms/step - accuracy: 0.9215 - auc: 0.9808 - loss: 0.2169 - precision: 0.8519 - recall: 0.9341 - val_accuracy: 0.8926 - val_auc: 0.9514 - val_loss: 0.3296 - val_precision: 0.8601 - val_recall: 0.7262 - learning_rate: 8.0000e-06
# Epoch 154/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 720ms/step - accuracy: 0.9154 - auc: 0.9801 - loss: 0.2208 - precision: 0.8418 - recall: 0.9284 - val_accuracy: 0.8870 - val_auc: 0.9518 - val_loss: 0.3331 - val_precision: 0.8592 - val_recall: 0.7032 - learning_rate: 8.0000e-06
# Epoch 155/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 695ms/step - accuracy: 0.9219 - auc: 0.9813 - loss: 0.2174 - precision: 0.8660 - recall: 0.9153 - val_accuracy: 0.8847 - val_auc: 0.9511 - val_loss: 0.3363 - val_precision: 0.8602 - val_recall: 0.6916 - learning_rate: 8.0000e-06
# Epoch 156/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 718ms/step - accuracy: 0.9205 - auc: 0.9788 - loss: 0.2248 - precision: 0.8565 - recall: 0.9244 - val_accuracy: 0.8847 - val_auc: 0.9515 - val_loss: 0.3369 - val_precision: 0.8602 - val_recall: 0.6916 - learning_rate: 8.0000e-06
# Epoch 157/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 690ms/step - accuracy: 0.9187 - auc: 0.9799 - loss: 0.2221 - precision: 0.8509 - recall: 0.9260 - val_accuracy: 0.8855 - val_auc: 0.9510 - val_loss: 0.3383 - val_precision: 0.8633 - val_recall: 0.6916 - learning_rate: 8.0000e-06
# Epoch 158/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 711ms/step - accuracy: 0.9205 - auc: 0.9816 - loss: 0.2161 - precision: 0.8582 - recall: 0.9216 - val_accuracy: 0.8855 - val_auc: 0.9517 - val_loss: 0.3397 - val_precision: 0.8633 - val_recall: 0.6916 - learning_rate: 8.0000e-06
# Epoch 159/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 676ms/step - accuracy: 0.9207 - auc: 0.9801 - loss: 0.2205 - precision: 0.8556 - recall: 0.9267 - val_accuracy: 0.8847 - val_auc: 0.9520 - val_loss: 0.3395 - val_precision: 0.8602 - val_recall: 0.6916 - learning_rate: 8.0000e-06
# Epoch 160/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 705ms/step - accuracy: 0.9165 - auc: 0.9805 - loss: 0.2199 - precision: 0.8468 - recall: 0.9242 - val_accuracy: 0.8918 - val_auc: 0.9511 - val_loss: 0.3393 - val_precision: 0.8646 - val_recall: 0.7176 - learning_rate: 8.0000e-06
# Epoch 161/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 688ms/step - accuracy: 0.9163 - auc: 0.9778 - loss: 0.2305 - precision: 0.8497 - recall: 0.9196 - val_accuracy: 0.8878 - val_auc: 0.9516 - val_loss: 0.3413 - val_precision: 0.8648 - val_recall: 0.7003 - learning_rate: 8.0000e-06
# Epoch 162/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 721ms/step - accuracy: 0.9198 - auc: 0.9800 - loss: 0.2205 - precision: 0.8469 - recall: 0.9361 - val_accuracy: 0.8720 - val_auc: 0.9513 - val_loss: 0.3457 - val_precision: 0.8571 - val_recall: 0.6398 - learning_rate: 8.0000e-06
# Epoch 163/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 689ms/step - accuracy: 0.9239 - auc: 0.9822 - loss: 0.2134 - precision: 0.8564 - recall: 0.9354 - val_accuracy: 0.8776 - val_auc: 0.9512 - val_loss: 0.3447 - val_precision: 0.8609 - val_recall: 0.6599 - learning_rate: 8.0000e-06
# Epoch 164/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 710ms/step - accuracy: 0.9168 - auc: 0.9792 - loss: 0.2265 - precision: 0.8540 - recall: 0.9151 - val_accuracy: 0.8744 - val_auc: 0.9512 - val_loss: 0.3437 - val_precision: 0.8588 - val_recall: 0.6484 - learning_rate: 8.0000e-06
# Epoch 165/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 689ms/step - accuracy: 0.9189 - auc: 0.9808 - loss: 0.2181 - precision: 0.8491 - recall: 0.9297 - val_accuracy: 0.8870 - val_auc: 0.9514 - val_loss: 0.3399 - val_precision: 0.8617 - val_recall: 0.7003 - learning_rate: 8.0000e-06
# Epoch 166/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 722ms/step - accuracy: 0.9158 - auc: 0.9804 - loss: 0.2190 - precision: 0.8491 - recall: 0.9189 - val_accuracy: 0.8886 - val_auc: 0.9508 - val_loss: 0.3425 - val_precision: 0.8679 - val_recall: 0.7003 - learning_rate: 8.0000e-06
# Epoch 167/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 688ms/step - accuracy: 0.9174 - auc: 0.9807 - loss: 0.2198 - precision: 0.8453 - recall: 0.9290 - val_accuracy: 0.8657 - val_auc: 0.9505 - val_loss: 0.3483 - val_precision: 0.8498 - val_recall: 0.6196 - learning_rate: 8.0000e-06
# Epoch 168/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 710ms/step - accuracy: 0.9213 - auc: 0.9823 - loss: 0.2129 - precision: 0.8497 - recall: 0.9366 - val_accuracy: 0.8752 - val_auc: 0.9511 - val_loss: 0.3479 - val_precision: 0.8566 - val_recall: 0.6542 - learning_rate: 8.0000e-06
# Epoch 169/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 687ms/step - accuracy: 0.9265 - auc: 0.9807 - loss: 0.2189 - precision: 0.8679 - recall: 0.9282 - val_accuracy: 0.8760 - val_auc: 0.9508 - val_loss: 0.3467 - val_precision: 0.8571 - val_recall: 0.6571 - learning_rate: 8.0000e-06
# Epoch 170/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 720ms/step - accuracy: 0.9193 - auc: 0.9796 - loss: 0.2233 - precision: 0.8567 - recall: 0.9191 - val_accuracy: 0.8760 - val_auc: 0.9495 - val_loss: 0.3466 - val_precision: 0.8571 - val_recall: 0.6571 - learning_rate: 8.0000e-06
# Epoch 171/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 701ms/step - accuracy: 0.9196 - auc: 0.9804 - loss: 0.2197 - precision: 0.8559 - recall: 0.9200 - val_accuracy: 0.8886 - val_auc: 0.9502 - val_loss: 0.3399 - val_precision: 0.8652 - val_recall: 0.7032 - learning_rate: 8.0000e-06
# Epoch 172/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 724ms/step - accuracy: 0.9172 - auc: 0.9788 - loss: 0.2263 - precision: 0.8478 - recall: 0.9265 - val_accuracy: 0.8934 - val_auc: 0.9498 - val_loss: 0.3423 - val_precision: 0.8655 - val_recall: 0.7233 - learning_rate: 8.0000e-06
# Epoch 173/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 690ms/step - accuracy: 0.9208 - auc: 0.9808 - loss: 0.2191 - precision: 0.8561 - recall: 0.9255 - val_accuracy: 0.8784 - val_auc: 0.9500 - val_loss: 0.3480 - val_precision: 0.8587 - val_recall: 0.6657 - learning_rate: 8.0000e-06
# Epoch 174/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 719ms/step - accuracy: 0.9311 - auc: 0.9837 - loss: 0.2084 - precision: 0.8671 - recall: 0.9449 - val_accuracy: 0.8886 - val_auc: 0.9501 - val_loss: 0.3426 - val_precision: 0.8652 - val_recall: 0.7032 - learning_rate: 8.0000e-06
# Epoch 175/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 695ms/step - accuracy: 0.9269 - auc: 0.9811 - loss: 0.2151 - precision: 0.8655 - recall: 0.9324 - val_accuracy: 0.8823 - val_auc: 0.9502 - val_loss: 0.3444 - val_precision: 0.8587 - val_recall: 0.6830 - learning_rate: 8.0000e-06
# Epoch 176/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 720ms/step - accuracy: 0.9243 - auc: 0.9823 - loss: 0.2143 - precision: 0.8581 - recall: 0.9345 - val_accuracy: 0.8720 - val_auc: 0.9506 - val_loss: 0.3499 - val_precision: 0.8517 - val_recall: 0.6455 - learning_rate: 8.0000e-06
# Epoch 177/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 694ms/step - accuracy: 0.9240 - auc: 0.9800 - loss: 0.2212 - precision: 0.8603 - recall: 0.9308 - val_accuracy: 0.8839 - val_auc: 0.9502 - val_loss: 0.3490 - val_precision: 0.8623 - val_recall: 0.6859 - learning_rate: 8.0000e-06
# Epoch 178/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 702ms/step - accuracy: 0.9243 - auc: 0.9815 - loss: 0.2161 - precision: 0.8642 - recall: 0.9253 - val_accuracy: 0.8902 - val_auc: 0.9496 - val_loss: 0.3456 - val_precision: 0.8636 - val_recall: 0.7118 - learning_rate: 8.0000e-06
# Epoch 179/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 684ms/step - accuracy: 0.9165 - auc: 0.9802 - loss: 0.2214 - precision: 0.8513 - recall: 0.9181 - val_accuracy: 0.8815 - val_auc: 0.9494 - val_loss: 0.3502 - val_precision: 0.8635 - val_recall: 0.6744 - learning_rate: 8.0000e-06
# Epoch 180/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 709ms/step - accuracy: 0.9201 - auc: 0.9792 - loss: 0.2241 - precision: 0.8550 - recall: 0.9245 - val_accuracy: 0.8799 - val_auc: 0.9498 - val_loss: 0.3480 - val_precision: 0.8598 - val_recall: 0.6715 - learning_rate: 8.0000e-06
# Epoch 181/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 706ms/step - accuracy: 0.9162 - auc: 0.9815 - loss: 0.2150 - precision: 0.8393 - recall: 0.9350 - val_accuracy: 0.8776 - val_auc: 0.9497 - val_loss: 0.3513 - val_precision: 0.8636 - val_recall: 0.6571 - learning_rate: 8.0000e-06
# Epoch 182/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 707ms/step - accuracy: 0.9175 - auc: 0.9793 - loss: 0.2242 - precision: 0.8498 - recall: 0.9242 - val_accuracy: 0.8799 - val_auc: 0.9504 - val_loss: 0.3476 - val_precision: 0.8652 - val_recall: 0.6657 - learning_rate: 8.0000e-06
# Epoch 183/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 709ms/step - accuracy: 0.9285 - auc: 0.9852 - loss: 0.2018 - precision: 0.8658 - recall: 0.9373 - val_accuracy: 0.8823 - val_auc: 0.9508 - val_loss: 0.3470 - val_precision: 0.8640 - val_recall: 0.6772 - learning_rate: 8.0000e-06
# Epoch 184/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 702ms/step - accuracy: 0.9247 - auc: 0.9821 - loss: 0.2130 - precision: 0.8557 - recall: 0.9401 - val_accuracy: 0.8957 - val_auc: 0.9510 - val_loss: 0.3447 - val_precision: 0.8669 - val_recall: 0.7320 - learning_rate: 8.0000e-06
# Epoch 185/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 715ms/step - accuracy: 0.9242 - auc: 0.9809 - loss: 0.2171 - precision: 0.8581 - recall: 0.9337 - val_accuracy: 0.8831 - val_auc: 0.9503 - val_loss: 0.3474 - val_precision: 0.8541 - val_recall: 0.6916 - learning_rate: 8.0000e-06
# Epoch 186/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 698ms/step - accuracy: 0.9293 - auc: 0.9828 - loss: 0.2120 - precision: 0.8709 - recall: 0.9331 - val_accuracy: 0.8863 - val_auc: 0.9508 - val_loss: 0.3458 - val_precision: 0.8664 - val_recall: 0.6916 - learning_rate: 8.0000e-06
# Epoch 187/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 720ms/step - accuracy: 0.9174 - auc: 0.9820 - loss: 0.2130 - precision: 0.8476 - recall: 0.9266 - val_accuracy: 0.8736 - val_auc: 0.9509 - val_loss: 0.3538 - val_precision: 0.8582 - val_recall: 0.6455 - learning_rate: 8.0000e-06
# Epoch 188/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 696ms/step - accuracy: 0.9215 - auc: 0.9817 - loss: 0.2153 - precision: 0.8554 - recall: 0.9294 - val_accuracy: 0.8815 - val_auc: 0.9504 - val_loss: 0.3481 - val_precision: 0.8662 - val_recall: 0.6715 - learning_rate: 8.0000e-06
# Epoch 189/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 698ms/step - accuracy: 0.9284 - auc: 0.9841 - loss: 0.2065 - precision: 0.8621 - recall: 0.9422 - val_accuracy: 0.8705 - val_auc: 0.9494 - val_loss: 0.3541 - val_precision: 0.8560 - val_recall: 0.6340 - learning_rate: 8.0000e-06
# Epoch 190/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 705ms/step - accuracy: 0.9238 - auc: 0.9825 - loss: 0.2123 - precision: 0.8626 - recall: 0.9257 - val_accuracy: 0.8839 - val_auc: 0.9497 - val_loss: 0.3486 - val_precision: 0.8650 - val_recall: 0.6830 - learning_rate: 8.0000e-06
# Epoch 191/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 708ms/step - accuracy: 0.9250 - auc: 0.9841 - loss: 0.2057 - precision: 0.8590 - recall: 0.9351 - val_accuracy: 0.8776 - val_auc: 0.9502 - val_loss: 0.3507 - val_precision: 0.8636 - val_recall: 0.6571 - learning_rate: 8.0000e-06
# Epoch 192/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 705ms/step - accuracy: 0.9273 - auc: 0.9832 - loss: 0.2084 - precision: 0.8624 - recall: 0.9386 - val_accuracy: 0.8784 - val_auc: 0.9449 - val_loss: 0.3527 - val_precision: 0.8614 - val_recall: 0.6628 - learning_rate: 8.0000e-06
# Epoch 193/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 710ms/step - accuracy: 0.9221 - auc: 0.9803 - loss: 0.2200 - precision: 0.8568 - recall: 0.9284 - val_accuracy: 0.8784 - val_auc: 0.9446 - val_loss: 0.3578 - val_precision: 0.8614 - val_recall: 0.6628 - learning_rate: 8.0000e-06
# Epoch 194/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 701ms/step - accuracy: 0.9301 - auc: 0.9842 - loss: 0.2052 - precision: 0.8649 - recall: 0.9447 - val_accuracy: 0.8720 - val_auc: 0.9449 - val_loss: 0.3560 - val_precision: 0.8599 - val_recall: 0.6369 - learning_rate: 8.0000e-06
# Epoch 195/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 710ms/step - accuracy: 0.9243 - auc: 0.9836 - loss: 0.2071 - precision: 0.8565 - recall: 0.9373 - val_accuracy: 0.8791 - val_auc: 0.9500 - val_loss: 0.3509 - val_precision: 0.8647 - val_recall: 0.6628 - learning_rate: 8.0000e-06
# Epoch 196/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 696ms/step - accuracy: 0.9114 - auc: 0.9794 - loss: 0.2236 - precision: 0.8324 - recall: 0.9297 - val_accuracy: 0.8791 - val_auc: 0.9500 - val_loss: 0.3504 - val_precision: 0.8647 - val_recall: 0.6628 - learning_rate: 8.0000e-06
# Epoch 197/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 706ms/step - accuracy: 0.9276 - auc: 0.9840 - loss: 0.2065 - precision: 0.8621 - recall: 0.9406 - val_accuracy: 0.8744 - val_auc: 0.9495 - val_loss: 0.3532 - val_precision: 0.8615 - val_recall: 0.6455 - learning_rate: 8.0000e-06
# Epoch 198/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 701ms/step - accuracy: 0.9236 - auc: 0.9835 - loss: 0.2070 - precision: 0.8554 - recall: 0.9373 - val_accuracy: 0.8784 - val_auc: 0.9498 - val_loss: 0.3533 - val_precision: 0.8669 - val_recall: 0.6571 - learning_rate: 8.0000e-06
# Epoch 199/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 706ms/step - accuracy: 0.9310 - auc: 0.9835 - loss: 0.2076 - precision: 0.8732 - recall: 0.9353 - val_accuracy: 0.8823 - val_auc: 0.9498 - val_loss: 0.3520 - val_precision: 0.8694 - val_recall: 0.6715 - learning_rate: 8.0000e-06
# Epoch 200/200
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 20s 694ms/step - accuracy: 0.9275 - auc: 0.9830 - loss: 0.2100 - precision: 0.8660 - recall: 0.9341 - val_accuracy: 0.8831 - val_auc: 0.9493 - val_loss: 0.3518 - val_precision: 0.8699 - val_recall: 0.6744 - learning_rate: 8.0000e-06

# %%
# Assuming `history` is the output from model.fit() that contains training logs

# Extract Loss, Accuracy, and AUC from history
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
auc = history.history['auc']
val_auc = history.history['val_auc']
epochs = range(1, len(loss) + 1)

# Find the epoch with the maximum val_auc
max_val_auc_epoch = np.argmax(val_auc)
max_val_auc = val_auc[max_val_auc_epoch]

# Plotting Loss
plt.figure(figsize=(12, 8))
plt.subplot(2, 1, 1)
plt.plot(epochs, loss, 'o-', label='Training Loss', markersize=5, color='tab:blue')
plt.plot(epochs, val_loss, 's-', label='Validation Loss', markersize=5, color='tab:orange')
plt.title('Training and Validation Loss', fontsize=14)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend(loc='upper right', fontsize=12)
plt.grid(True)

# Plotting Accuracy
plt.subplot(2, 1, 2)
plt.plot(epochs, accuracy, 'o-', label='Training Accuracy', markersize=5, color='tab:blue')
plt.plot(epochs, val_accuracy, 's-', label='Validation Accuracy', markersize=5, color='tab:orange')
plt.title('Training and Validation Accuracy', fontsize=14)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)

# Display both Loss and Accuracy plots
plt.tight_layout()
plt.show()

# Plotting AUC
plt.figure(figsize=(10, 6))
plt.plot(epochs, auc, 'o-', label='Training AUC', markersize=5, color='tab:blue')
plt.plot(epochs, val_auc, 's-', label='Validation AUC', markersize=5, color='tab:orange')

# Highlight the max val_auc
plt.scatter(max_val_auc_epoch + 1, max_val_auc, color='red', s=100, label=f'Max Val AUC: {max_val_auc:.4f}')
plt.annotate(f'Max Val AUC: {max_val_auc:.4f}',
             xy=(max_val_auc_epoch + 1, max_val_auc),
             xytext=(max_val_auc_epoch + 1 + 0.5, max_val_auc - 0.05),
             arrowprops=dict(facecolor='black', arrowstyle="->"),
             fontsize=12,
             color='tab:red')

# Enhancing the plot
plt.title('AUC over Epochs', fontsize=14)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('AUC', fontsize=12)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.xticks(epochs)

# Show the plot
plt.show()

# %% [markdown]
# ## Visualize AUC with Epochs

# %%
# Extract AUC and validation AUC from history
auc = history.history['auc']
val_auc = history.history['val_auc']
epochs = range(1, len(auc) + 1)

# Find the epoch with the maximum val_auc
max_val_auc_epoch = np.argmax(val_auc)
max_val_auc = val_auc[max_val_auc_epoch]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(epochs, auc, 'o-', label='Training AUC', markersize=5, color='tab:blue')
plt.plot(epochs, val_auc, 's-', label='Validation AUC', markersize=5, color='tab:orange')

# Highlight the max val_auc
plt.scatter(max_val_auc_epoch + 1, max_val_auc, color='red', s=100, label=f'Max Val AUC: {max_val_auc:.4f}')
plt.annotate(f'Max Val AUC: {max_val_auc:.4f}',
             xy=(max_val_auc_epoch + 1, max_val_auc),
             xytext=(max_val_auc_epoch + 1 + 0.5, max_val_auc - 0.05),
             arrowprops=dict(facecolor='black', arrowstyle="->"),
             fontsize=12,
             color='tab:red')

# Enhancing the plot
plt.title('AUC over Epochs', fontsize=14)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('AUC', fontsize=12)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.xticks(epochs)

# Show the plot
plt.show()

# %% [markdown]
# #| Result

# %%
# Best Result
best_score = max(history.history['val_auc'])
best_epoch = np.argmax(history.history['val_auc']) + 1
print("#" * 10 + " Result " + "#" * 10)
print(f"Best AUC: {best_score:.5f}")
print(f"Best Epoch: {best_epoch}")
print("#" * 28)
# Out:
# ########## Result ##########
# Best AUC: 0.95678
# Best Epoch: 12
# ############################

# %% [markdown]
# **bold text**# | Prediction

# %% [markdown]
# ## Load Best Model

# %%
model.load_weights("best_model.keras")

# %% [markdown]
# ## Build Testing Dataset
#
# Don't forget to normalize for the testing data as well.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# Function to generate model report
def generate_model_report(model, validation_ds, threshold=0.5):
    # Predict the probabilities on the validation set
    y_pred_probs = model.predict(validation_ds)

    # Convert probabilities to binary predictions using the threshold
    y_pred = (y_pred_probs > threshold).astype(int)

    # Get the true labels (assuming validation_ds yields tuples (features, labels))
    y_true = np.concatenate([y for _, y in validation_ds], axis=0)

    # Generate classification report and confusion matrix
    report = classification_report(y_true, y_pred, target_names=["Benign", "Malignant"])
    cm = confusion_matrix(y_true, y_pred)

    print("Classification Report:\n", report)

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=["Benign", "Malignant"], yticklabels=["Benign", "Malignant"])
    plt.title("Confusion Matrix")
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# Load the model architecture and weights
model.load_weights("best_model.keras")  # Load weights from the pre-built model

# Generate the classification report and confusion matrix using the validation set
generate_model_report(model, validation_ds)

# Print the model summary (optional, for debugging purposes)
model.summary()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Benign       0.93      0.94      0.94       919
#    Malignant       0.84      0.81      0.83       347
#
#     accuracy                           0.91      1266
#    macro avg       0.89      0.88      0.88      1266
# weighted avg       0.91      0.91      0.91      1266
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ images (InputLayer) │ (None, 128, 128,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ features            │ (None, 71)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ efficient_net_v2b2… │ (None, 4, 4,      │  8,769,374 │ images[0][0]      │
# │ (EfficientNetV2Bac… │ 1408)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 96)        │      6,912 │ features[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1408)      │          0 │ efficient_net_v2… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │     12,416 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1408)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 1536)      │          0 │ dropout[0][0],    │
# │ (Concatenate)       │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │      1,537 │ concatenate_1[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 26,206,143 (99.97 MB)
#  Trainable params: 8,707,951 (33.22 MB)
#  Non-trainable params: 82,288 (321.44 KB)
#  Optimizer params: 17,415,904 (66.44 MB)

# %%
# Testing
print("# Testing:")
testing_features = dict(testing_df[FEAT_COLS])
testing_ids = testing_df.isic_id.values
testing_ds = build_dataset(testing_ids, testing_hdf5,
                        testing_features, batch_size=CFG.batch_size,
                         shuffle=False, augment=False, cache=False)
# Apply feature space processing
testing_ds = testing_ds.map(
    lambda x: {"images": x["images"],
               "features": feature_space(x["features"])}, num_parallel_calls=tf.data.AUTOTUNE)
# Out:
# # Testing:
# Loading Images :   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ## Inference

# %%
preds = model.predict(testing_ds).squeeze()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step

# %% [markdown]
# ## Check Prediction

# %%
inputs = next(iter(testing_ds))
images = inputs["images"]

# Plotting
plt.figure(figsize=(10, 4))

for i in range(3):
    plt.subplot(1, 3, i+1)  # 1 row, 3 columns, i+1th subplot
    plt.imshow(images[i])  # Show image
    plt.title(f'Prediction: {preds[i]:.2f}')  # Set title with prediction
    plt.axis('off')  # Hide axis

plt.suptitle('Model Predictions on Testing Images', fontsize=16)
plt.tight_layout()
plt.show()
